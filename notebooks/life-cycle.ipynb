# %% [markdown]
# # 1) Data Extraction

# %%
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm

# %%
filenames = []
for file in os.listdir('t20s'):
    filenames.append(os.path.join('t20s',file))

# %%
filenames[0:5]
# Out:
# ['t20s\\1001349.yaml',
#  't20s\\1001351.yaml',
#  't20s\\1001353.yaml',
#  't20s\\1004729.yaml',
#  't20s\\1007655.yaml']

# %%
final_df = pd.DataFrame()
counter = 1
for file in tqdm(filenames):
    with open(file, 'r') as f:
        df = pd.json_normalize(safe_load(f))
        df['match_id'] = counter
        final_df = pd.concat([final_df, df], ignore_index=True)
        counter+=1
        
final_df
# Out:
# 100%|█████████▉| 4221/4222 [1:44:31<00:01,  1.49s/it]
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[11], line 5
#       3 for file in tqdm(filenames):
#       4     with open(file, 'r') as f:
# ----> 5         df = pd.json_normalize(safe_load(f))
#       6         df['match_id'] = counter
#       7         final_df = pd.concat([final_df, df], ignore_index=True)
#
# File c:\Users\srika\anaconda3\envs\atlas310\lib\site-packages\pandas\io\json\_normalize.py:445, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     443     data = list(data)
#     444 else:
# --> 445     raise NotImplementedError
#     447 # check to see if a simple recursive function is possible to
#     448 # improve performance (see #15621) but only for cases such
#     449 # as pd.Dataframe(data) or pd.Dataframe(data, sep)
#     450 if (
#     451     record_path is None
#     452     and meta is None
#    (...)
#     455     and max_level is None
#     456 ):
#
# NotImplementedError:

# %%
final_df
# Out:
#                                                 innings  meta.data_version  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 1     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 2     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 3     [{'1st innings': {'team': 'Hong Kong', 'delive...               0.91
# 4     [{'1st innings': {'team': 'Zimbabwe', 'deliver...               0.91
# ...                                                 ...                ...
# 4216  [{'1st innings': {'team': 'Sri Lanka', 'delive...               0.91
# 4217  [{'1st innings': {'team': 'Bangladesh', 'deliv...               0.91
# 4218  [{'1st innings': {'team': 'Netherlands', 'deli...               0.91
# 4219  [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 4220  [{'1st innings': {'team': 'Sri Lanka', 'delive...               0.91
#
#      meta.created  meta.revision  info.balls_per_over    info.dates  \
# 0      2017-02-18              2                    6  [2017-02-17]
# 1      2017-02-19              2                    6  [2017-02-19]
# 2      2017-02-23              1                    6  [2017-02-22]
# 3      2016-09-12              1                    6  [2016-09-05]
# 4      2016-06-19              1                    6  [2016-06-18]
# ...           ...            ...                  ...           ...
# 4216   2016-03-05              2                    6  [2016-03-04]
# 4217   2016-03-08              1                    6  [2016-03-06]
# 4218   2016-02-03              1                    6  [2016-02-03]
# 4219   2016-09-12              1                    6  [2016-09-06]
# 4220   2016-09-12              1                    6  [2016-09-09]
#
#      info.gender info.match_type  info.outcome.by.wickets info.outcome.winner  \
# 0           male             T20                      5.0           Sri Lanka
# 1           male             T20                      2.0           Sri Lanka
# 2           male             T20                      NaN           Australia
# 3           male             T20                      NaN           Hong Kong
# 4           male             T20                      NaN            Zimbabwe
# ...          ...             ...                      ...                 ...
# 4216        male             T20                      6.0            Pakistan
# 4217        male             T20                      8.0               India
# 4218        male             T20                      NaN         Netherlands
# 4219        male             T20                      NaN           Australia
# 4220        male             T20                      4.0           Australia
#
#       ...  info.registry.people.Muhammad Kaleem  \
# 0     ...                                   NaN
# 1     ...                                   NaN
# 2     ...                                   NaN
# 3     ...                                   NaN
# 4     ...                                   NaN
# ...   ...                                   ...
# 4216  ...                                   NaN
# 4217  ...                                   NaN
# 4218  ...                                   NaN
# 4219  ...                                   NaN
# 4220  ...                                   NaN
#
#      info.registry.people.Usman Mushtaq info.registry.people.Mohammad Shahid  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
# ...                                 ...                                  ...
# 4216                                NaN                                  NaN
# 4217                                NaN                                  NaN
# 4218                                NaN                                  NaN
# 4219                                NaN                                  NaN
# 4220                                NaN                                  NaN
#
#      info.registry.people.Muktar Ali info.registry.people.Mohammad Usman  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
# ...                              ...                                 ...
# 4216                             NaN                                 NaN
# 4217                             NaN                                 NaN
# 4218                             NaN                            cee89f44
# 4219                             NaN                                 NaN
# 4220                             NaN                                 NaN
#
#      info.registry.people.VS Wategaonkar info.registry.people.Farhan Ahmed  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
# ...                                  ...                               ...
# 4216                                 NaN                               NaN
# 4217                                 NaN                               NaN
# 4218                                 NaN                          927694f7
# 4219                                 NaN                               NaN
# 4220                                 NaN                               NaN
#
#      info.registry.people.Khurram Manzoor info.registry.people.P Negi  \
# 0                                     NaN                         NaN
# 1                                     NaN                         NaN
# 2                                     NaN                         NaN
# 3                                     NaN                         NaN
# 4                                     NaN                         NaN
# ...                                   ...                         ...
# 4216                                  NaN                         NaN
# 4217                                  NaN                         NaN
# 4218                                  NaN                         NaN
# 4219                                  NaN                         NaN
# 4220                                  NaN                         NaN
#
#      info.registry.people.Hafiz Qaleem
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 4216                               NaN
# 4217                               NaN
# 4218                          f566cd7d
# 4219                               NaN
# 4220                               NaN
#
# [4221 rows x 7326 columns]

# %% [markdown]
# # 2) Data Cleaning, Feature Extraction, and Feature Engineering

# %%
final_df = final_df[['innings','info.dates','info.gender','info.match_type','info.outcome.winner','info.overs','info.player_of_match','info.teams','info.toss.decision','info.toss.winner','info.umpires','info.venue','match_id','info.city']]

# %%
# final_df.to_csv('final_df.csv', index=False)

# %%
# final_df = pd.read_csv('final_df.csv')

# %%
final_df
# Out:
#                                                 innings    info.dates  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 1     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 2     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 3     [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 4     [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ...                                                 ...           ...
# 4216  [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 4217  [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# 4218  [{'1st innings': {'team': 'Netherlands', 'deli...  [2016-02-03]
# 4219  [{'1st innings': {'team': 'Australia', 'delive...  [2016-09-06]
# 4220  [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-09-09]
#
#      info.gender info.match_type info.outcome.winner  info.overs  \
# 0           male             T20           Sri Lanka          20
# 1           male             T20           Sri Lanka          20
# 2           male             T20           Australia          20
# 3           male             T20           Hong Kong          20
# 4           male             T20            Zimbabwe          20
# ...          ...             ...                 ...         ...
# 4216        male             T20            Pakistan          20
# 4217        male             T20               India          20
# 4218        male             T20         Netherlands          20
# 4219        male             T20           Australia          20
# 4220        male             T20           Australia          20
#
#      info.player_of_match                           info.teams  \
# 0         [DAS Gunaratne]               [Australia, Sri Lanka]
# 1         [DAS Gunaratne]               [Australia, Sri Lanka]
# 2               [A Zampa]               [Australia, Sri Lanka]
# 3                     NaN                 [Ireland, Hong Kong]
# 4          [E Chigumbura]                    [Zimbabwe, India]
# ...                   ...                                  ...
# 4216         [Umar Akmal]                [Pakistan, Sri Lanka]
# 4217           [S Dhawan]                  [Bangladesh, India]
# 4218   [Mudassar Bukhari]  [United Arab Emirates, Netherlands]
# 4219         [GJ Maxwell]               [Sri Lanka, Australia]
# 4220         [GJ Maxwell]               [Sri Lanka, Australia]
#
#      info.toss.decision      info.toss.winner  \
# 0                 field             Sri Lanka
# 1                 field             Sri Lanka
# 2                 field             Sri Lanka
# 3                   bat             Hong Kong
# 4                 field                 India
# ...                 ...                   ...
# 4216              field              Pakistan
# 4217              field                 India
# 4218              field  United Arab Emirates
# 4219              field             Sri Lanka
# 4220                bat             Sri Lanka
#
#                             info.umpires  \
# 0                 [MD Martell, P Wilson]
# 1                  [SD Fry, SJ Nogajski]
# 2                 [MD Martell, P Wilson]
# 3                    [R Black, AJ Neill]
# 4               [TJ Matibiri, RB Tiffin]
# ...                                  ...
# 4216        [AK Chaudhary, Enamul Haque]
# 4217    [RSA Palliyaguruge, Shozab Raza]
# 4218          [CK Nandan, Sarika Prasad]
# 4219      [REJ Martinesz, RR Wimalasiri]
# 4220  [REJ Martinesz, RSA Palliyaguruge]
#
#                                    info.venue  match_id    info.city
# 0                    Melbourne Cricket Ground         1          NaN
# 1              Simonds Stadium, South Geelong         2     Victoria
# 2                               Adelaide Oval         3          NaN
# 3           Bready Cricket Club, Magheramason         4  Londonderry
# 4                          Harare Sports Club         5          NaN
# ...                                       ...       ...          ...
# 4216            Shere Bangla National Stadium      4217       Mirpur
# 4217            Shere Bangla National Stadium      4218       Mirpur
# 4218                              ICC Academy      4219        Dubai
# 4219  Pallekele International Cricket Stadium      4220          NaN
# 4220                      R Premadasa Stadium      4221      Colombo
#
# [4221 rows x 14 columns]

# %%
final_df['info.gender'].value_counts()
# Out:
# info.gender
# male      2696
# female    1525
# Name: count, dtype: int64

# %%
final_df = final_df[final_df['info.gender'] == 'male']
final_df.drop(columns=['info.gender'],inplace=True)
final_df
# Out:
# C:\Users\srika\AppData\Local\Temp\ipykernel_33196\2142223783.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.gender'],inplace=True)
#                                                 innings    info.dates  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 1     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 2     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 3     [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 4     [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ...                                                 ...           ...
# 4216  [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 4217  [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# 4218  [{'1st innings': {'team': 'Netherlands', 'deli...  [2016-02-03]
# 4219  [{'1st innings': {'team': 'Australia', 'delive...  [2016-09-06]
# 4220  [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-09-09]
#
#      info.match_type info.outcome.winner  info.overs info.player_of_match  \
# 0                T20           Sri Lanka          20      [DAS Gunaratne]
# 1                T20           Sri Lanka          20      [DAS Gunaratne]
# 2                T20           Australia          20            [A Zampa]
# 3                T20           Hong Kong          20                  NaN
# 4                T20            Zimbabwe          20       [E Chigumbura]
# ...              ...                 ...         ...                  ...
# 4216             T20            Pakistan          20         [Umar Akmal]
# 4217             T20               India          20           [S Dhawan]
# 4218             T20         Netherlands          20   [Mudassar Bukhari]
# 4219             T20           Australia          20         [GJ Maxwell]
# 4220             T20           Australia          20         [GJ Maxwell]
#
#                                info.teams info.toss.decision  \
# 0                  [Australia, Sri Lanka]              field
# 1                  [Australia, Sri Lanka]              field
# 2                  [Australia, Sri Lanka]              field
# 3                    [Ireland, Hong Kong]                bat
# 4                       [Zimbabwe, India]              field
# ...                                   ...                ...
# 4216                [Pakistan, Sri Lanka]              field
# 4217                  [Bangladesh, India]              field
# 4218  [United Arab Emirates, Netherlands]              field
# 4219               [Sri Lanka, Australia]              field
# 4220               [Sri Lanka, Australia]                bat
#
#           info.toss.winner                        info.umpires  \
# 0                Sri Lanka              [MD Martell, P Wilson]
# 1                Sri Lanka               [SD Fry, SJ Nogajski]
# 2                Sri Lanka              [MD Martell, P Wilson]
# 3                Hong Kong                 [R Black, AJ Neill]
# 4                    India            [TJ Matibiri, RB Tiffin]
# ...                    ...                                 ...
# 4216              Pakistan        [AK Chaudhary, Enamul Haque]
# 4217                 India    [RSA Palliyaguruge, Shozab Raza]
# 4218  United Arab Emirates          [CK Nandan, Sarika Prasad]
# 4219             Sri Lanka      [REJ Martinesz, RR Wimalasiri]
# 4220             Sri Lanka  [REJ Martinesz, RSA Palliyaguruge]
#
#                                    info.venue  match_id    info.city
# 0                    Melbourne Cricket Ground         1          NaN
# 1              Simonds Stadium, South Geelong         2     Victoria
# 2                               Adelaide Oval         3          NaN
# 3           Bready Cricket Club, Magheramason         4  Londonderry
# 4                          Harare Sports Club         5          NaN
# ...                                       ...       ...          ...
# 4216            Shere Bangla National Stadium      4217       Mirpur
# 4217            Shere Bangla National Stadium      4218       Mirpur
# 4218                              ICC Academy      4219        Dubai
# 4219  Pallekele International Cricket Stadium      4220          NaN
# 4220                      R Premadasa Stadium      4221      Colombo
#
# [2696 rows x 13 columns]

# %%
final_df['info.match_type'].value_counts()
# Out:
# info.match_type
# T20    2696
# Name: count, dtype: int64

# %%
final_df = final_df[final_df['info.overs'] == 20]
final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
final_df
# Out:
# C:\Users\srika\AppData\Local\Temp\ipykernel_33196\3157072726.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
#                                                 innings    info.dates  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 1     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 2     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 3     [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 4     [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ...                                                 ...           ...
# 4216  [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 4217  [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# 4218  [{'1st innings': {'team': 'Netherlands', 'deli...  [2016-02-03]
# 4219  [{'1st innings': {'team': 'Australia', 'delive...  [2016-09-06]
# 4220  [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-09-09]
#
#      info.outcome.winner info.player_of_match  \
# 0              Sri Lanka      [DAS Gunaratne]
# 1              Sri Lanka      [DAS Gunaratne]
# 2              Australia            [A Zampa]
# 3              Hong Kong                  NaN
# 4               Zimbabwe       [E Chigumbura]
# ...                  ...                  ...
# 4216            Pakistan         [Umar Akmal]
# 4217               India           [S Dhawan]
# 4218         Netherlands   [Mudassar Bukhari]
# 4219           Australia         [GJ Maxwell]
# 4220           Australia         [GJ Maxwell]
#
#                                info.teams info.toss.decision  \
# 0                  [Australia, Sri Lanka]              field
# 1                  [Australia, Sri Lanka]              field
# 2                  [Australia, Sri Lanka]              field
# 3                    [Ireland, Hong Kong]                bat
# 4                       [Zimbabwe, India]              field
# ...                                   ...                ...
# 4216                [Pakistan, Sri Lanka]              field
# 4217                  [Bangladesh, India]              field
# 4218  [United Arab Emirates, Netherlands]              field
# 4219               [Sri Lanka, Australia]              field
# 4220               [Sri Lanka, Australia]                bat
#
#           info.toss.winner                        info.umpires  \
# 0                Sri Lanka              [MD Martell, P Wilson]
# 1                Sri Lanka               [SD Fry, SJ Nogajski]
# 2                Sri Lanka              [MD Martell, P Wilson]
# 3                Hong Kong                 [R Black, AJ Neill]
# 4                    India            [TJ Matibiri, RB Tiffin]
# ...                    ...                                 ...
# 4216              Pakistan        [AK Chaudhary, Enamul Haque]
# 4217                 India    [RSA Palliyaguruge, Shozab Raza]
# 4218  United Arab Emirates          [CK Nandan, Sarika Prasad]
# 4219             Sri Lanka      [REJ Martinesz, RR Wimalasiri]
# 4220             Sri Lanka  [REJ Martinesz, RSA Palliyaguruge]
#
#                                    info.venue  match_id    info.city
# 0                    Melbourne Cricket Ground         1          NaN
# 1              Simonds Stadium, South Geelong         2     Victoria
# 2                               Adelaide Oval         3          NaN
# 3           Bready Cricket Club, Magheramason         4  Londonderry
# 4                          Harare Sports Club         5          NaN
# ...                                       ...       ...          ...
# 4216            Shere Bangla National Stadium      4217       Mirpur
# 4217            Shere Bangla National Stadium      4218       Mirpur
# 4218                              ICC Academy      4219        Dubai
# 4219  Pallekele International Cricket Stadium      4220          NaN
# 4220                      R Premadasa Stadium      4221      Colombo
#
# [2690 rows x 11 columns]

# %%
final_df
# Out:
#                                                 innings    info.dates  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 1     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 2     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 3     [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 4     [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ...                                                 ...           ...
# 4216  [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 4217  [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# 4218  [{'1st innings': {'team': 'Netherlands', 'deli...  [2016-02-03]
# 4219  [{'1st innings': {'team': 'Australia', 'delive...  [2016-09-06]
# 4220  [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-09-09]
#
#      info.outcome.winner info.player_of_match  \
# 0              Sri Lanka      [DAS Gunaratne]
# 1              Sri Lanka      [DAS Gunaratne]
# 2              Australia            [A Zampa]
# 3              Hong Kong                  NaN
# 4               Zimbabwe       [E Chigumbura]
# ...                  ...                  ...
# 4216            Pakistan         [Umar Akmal]
# 4217               India           [S Dhawan]
# 4218         Netherlands   [Mudassar Bukhari]
# 4219           Australia         [GJ Maxwell]
# 4220           Australia         [GJ Maxwell]
#
#                                info.teams info.toss.decision  \
# 0                  [Australia, Sri Lanka]              field
# 1                  [Australia, Sri Lanka]              field
# 2                  [Australia, Sri Lanka]              field
# 3                    [Ireland, Hong Kong]                bat
# 4                       [Zimbabwe, India]              field
# ...                                   ...                ...
# 4216                [Pakistan, Sri Lanka]              field
# 4217                  [Bangladesh, India]              field
# 4218  [United Arab Emirates, Netherlands]              field
# 4219               [Sri Lanka, Australia]              field
# 4220               [Sri Lanka, Australia]                bat
#
#           info.toss.winner                        info.umpires  \
# 0                Sri Lanka              [MD Martell, P Wilson]
# 1                Sri Lanka               [SD Fry, SJ Nogajski]
# 2                Sri Lanka              [MD Martell, P Wilson]
# 3                Hong Kong                 [R Black, AJ Neill]
# 4                    India            [TJ Matibiri, RB Tiffin]
# ...                    ...                                 ...
# 4216              Pakistan        [AK Chaudhary, Enamul Haque]
# 4217                 India    [RSA Palliyaguruge, Shozab Raza]
# 4218  United Arab Emirates          [CK Nandan, Sarika Prasad]
# 4219             Sri Lanka      [REJ Martinesz, RR Wimalasiri]
# 4220             Sri Lanka  [REJ Martinesz, RSA Palliyaguruge]
#
#                                    info.venue  match_id    info.city
# 0                    Melbourne Cricket Ground         1          NaN
# 1              Simonds Stadium, South Geelong         2     Victoria
# 2                               Adelaide Oval         3          NaN
# 3           Bready Cricket Club, Magheramason         4  Londonderry
# 4                          Harare Sports Club         5          NaN
# ...                                       ...       ...          ...
# 4216            Shere Bangla National Stadium      4217       Mirpur
# 4217            Shere Bangla National Stadium      4218       Mirpur
# 4218                              ICC Academy      4219        Dubai
# 4219  Pallekele International Cricket Stadium      4220          NaN
# 4220                      R Premadasa Stadium      4221      Colombo
#
# [2690 rows x 11 columns]

# %%
final_df.to_csv('dataset_level1.csv',index=False)

# %%
final_df = pd.read_csv('dataset_level1.csv')

# %%
final_df
# Out:
#                                                 innings  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...
# 1     [{'1st innings': {'team': 'Australia', 'delive...
# 2     [{'1st innings': {'team': 'Australia', 'delive...
# 3     [{'1st innings': {'team': 'Hong Kong', 'delive...
# 4     [{'1st innings': {'team': 'Zimbabwe', 'deliver...
# ...                                                 ...
# 2685  [{'1st innings': {'team': 'Sri Lanka', 'delive...
# 2686  [{'1st innings': {'team': 'Bangladesh', 'deliv...
# 2687  [{'1st innings': {'team': 'Netherlands', 'deli...
# 2688  [{'1st innings': {'team': 'Australia', 'delive...
# 2689  [{'1st innings': {'team': 'Sri Lanka', 'delive...
#
#                         info.dates info.outcome.winner  info.player_of_match  \
# 0     [datetime.date(2017, 2, 17)]           Sri Lanka     ['DAS Gunaratne']
# 1     [datetime.date(2017, 2, 19)]           Sri Lanka     ['DAS Gunaratne']
# 2     [datetime.date(2017, 2, 22)]           Australia           ['A Zampa']
# 3      [datetime.date(2016, 9, 5)]           Hong Kong                   NaN
# 4     [datetime.date(2016, 6, 18)]            Zimbabwe      ['E Chigumbura']
# ...                            ...                 ...                   ...
# 2685   [datetime.date(2016, 3, 4)]            Pakistan        ['Umar Akmal']
# 2686   [datetime.date(2016, 3, 6)]               India          ['S Dhawan']
# 2687   [datetime.date(2016, 2, 3)]         Netherlands  ['Mudassar Bukhari']
# 2688   [datetime.date(2016, 9, 6)]           Australia        ['GJ Maxwell']
# 2689   [datetime.date(2016, 9, 9)]           Australia        ['GJ Maxwell']
#
#                                    info.teams info.toss.decision  \
# 0                  ['Australia', 'Sri Lanka']              field
# 1                  ['Australia', 'Sri Lanka']              field
# 2                  ['Australia', 'Sri Lanka']              field
# 3                    ['Ireland', 'Hong Kong']                bat
# 4                       ['Zimbabwe', 'India']              field
# ...                                       ...                ...
# 2685                ['Pakistan', 'Sri Lanka']              field
# 2686                  ['Bangladesh', 'India']              field
# 2687  ['United Arab Emirates', 'Netherlands']              field
# 2688               ['Sri Lanka', 'Australia']              field
# 2689               ['Sri Lanka', 'Australia']                bat
#
#           info.toss.winner                            info.umpires  \
# 0                Sri Lanka              ['MD Martell', 'P Wilson']
# 1                Sri Lanka               ['SD Fry', 'SJ Nogajski']
# 2                Sri Lanka              ['MD Martell', 'P Wilson']
# 3                Hong Kong                 ['R Black', 'AJ Neill']
# 4                    India            ['TJ Matibiri', 'RB Tiffin']
# ...                    ...                                     ...
# 2685              Pakistan        ['AK Chaudhary', 'Enamul Haque']
# 2686                 India    ['RSA Palliyaguruge', 'Shozab Raza']
# 2687  United Arab Emirates          ['CK Nandan', 'Sarika Prasad']
# 2688             Sri Lanka      ['REJ Martinesz', 'RR Wimalasiri']
# 2689             Sri Lanka  ['REJ Martinesz', 'RSA Palliyaguruge']
#
#                                    info.venue  match_id    info.city
# 0                    Melbourne Cricket Ground         1          NaN
# 1              Simonds Stadium, South Geelong         2     Victoria
# 2                               Adelaide Oval         3          NaN
# 3           Bready Cricket Club, Magheramason         4  Londonderry
# 4                          Harare Sports Club         5          NaN
# ...                                       ...       ...          ...
# 2685            Shere Bangla National Stadium      4217       Mirpur
# 2686            Shere Bangla National Stadium      4218       Mirpur
# 2687                              ICC Academy      4219        Dubai
# 2688  Pallekele International Cricket Stadium      4220          NaN
# 2689                      R Premadasa Stadium      4221      Colombo
#
# [2690 rows x 11 columns]

# %%
matches = final_df.copy()

# %%
matches.iloc[2211:]
# Out:
#                                                 innings  \
# 2211  [{'1st innings': {'team': 'England', 'deliveri...
# 2212  [{'1st innings': {'team': 'Australia', 'delive...
# 2213  [{'1st innings': {'team': 'South Africa', 'del...
# 2214  [{'1st innings': {'team': 'England', 'deliveri...
# 2215  [{'1st innings': {'team': 'Sri Lanka', 'delive...
# ...                                                 ...
# 2685  [{'1st innings': {'team': 'Sri Lanka', 'delive...
# 2686  [{'1st innings': {'team': 'Bangladesh', 'deliv...
# 2687  [{'1st innings': {'team': 'Netherlands', 'deli...
# 2688  [{'1st innings': {'team': 'Australia', 'delive...
# 2689  [{'1st innings': {'team': 'Sri Lanka', 'delive...
#
#                          info.dates info.outcome.winner  info.player_of_match  \
# 2211   [datetime.date(2005, 6, 13)]             England      ['KP Pietersen']
# 2212   [datetime.date(2005, 2, 17)]           Australia        ['RT Ponting']
# 2213  [datetime.date(2005, 10, 21)]         New Zealand          ['JS Patel']
# 2214   [datetime.date(2006, 8, 28)]            Pakistan     ['Shahid Afridi']
# 2215   [datetime.date(2006, 6, 15)]           Sri Lanka     ['ST Jayasuriya']
# ...                             ...                 ...                   ...
# 2685    [datetime.date(2016, 3, 4)]            Pakistan        ['Umar Akmal']
# 2686    [datetime.date(2016, 3, 6)]               India          ['S Dhawan']
# 2687    [datetime.date(2016, 2, 3)]         Netherlands  ['Mudassar Bukhari']
# 2688    [datetime.date(2016, 9, 6)]           Australia        ['GJ Maxwell']
# 2689    [datetime.date(2016, 9, 9)]           Australia        ['GJ Maxwell']
#
#                                    info.teams info.toss.decision  \
# 2211                 ['England', 'Australia']                bat
# 2212             ['New Zealand', 'Australia']                bat
# 2213          ['South Africa', 'New Zealand']              field
# 2214                  ['England', 'Pakistan']                bat
# 2215                 ['England', 'Sri Lanka']                bat
# ...                                       ...                ...
# 2685                ['Pakistan', 'Sri Lanka']              field
# 2686                  ['Bangladesh', 'India']              field
# 2687  ['United Arab Emirates', 'Netherlands']              field
# 2688               ['Sri Lanka', 'Australia']              field
# 2689               ['Sri Lanka', 'Australia']                bat
#
#           info.toss.winner                            info.umpires  \
# 2211               England               ['NJ Llong', 'JW Lloyds']
# 2212             Australia                ['BF Bowden', 'AL Hill']
# 2213           New Zealand             ['IL Howell', 'BG Jerling']
# 2214               England              ['PJ Hartley', 'NJ Llong']
# 2215             Sri Lanka                ['IJ Gould', 'NJ Llong']
# ...                    ...                                     ...
# 2685              Pakistan        ['AK Chaudhary', 'Enamul Haque']
# 2686                 India    ['RSA Palliyaguruge', 'Shozab Raza']
# 2687  United Arab Emirates          ['CK Nandan', 'Sarika Prasad']
# 2688             Sri Lanka      ['REJ Martinesz', 'RR Wimalasiri']
# 2689             Sri Lanka  ['REJ Martinesz', 'RSA Palliyaguruge']
#
#                                    info.venue  match_id     info.city
# 2211                            The Rose Bowl      3590   Southampton
# 2212                                Eden Park      3591      Auckland
# 2213                    New Wanderers Stadium      3592  Johannesburg
# 2214                            County Ground      3593       Bristol
# 2215                            The Rose Bowl      3594   Southampton
# ...                                       ...       ...           ...
# 2685            Shere Bangla National Stadium      4217        Mirpur
# 2686            Shere Bangla National Stadium      4218        Mirpur
# 2687                              ICC Academy      4219         Dubai
# 2688  Pallekele International Cricket Stadium      4220           NaN
# 2689                      R Premadasa Stadium      4221       Colombo
#
# [479 rows x 11 columns]

# %%
matches = pd.concat([matches.iloc[:1167],matches.iloc[2211:]]) # omitting 2023 beyond

# %%
# import ast

# def string_to_dict(s):
#     res = ast.literal_eval(s)
#     return res

# matches['innings'].apply(string_to_dict)
# # matches

# %%
import ast
import json
import pickle
import marshal
# matches.iloc[0]['innings']
ast.literal_eval(matches.iloc[0]['innings'])
# Out:
# [{'1st innings': {'team': 'Australia',
#    'deliveries': [{0.1: {'batsman': 'AJ Finch',
#       'bowler': 'SL Malinga',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {0.2: {'batsman': 'AJ Finch',
#       'bowler': 'SL Malinga',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {0.3: {'batsman': 'AJ Finch',
#       'bowler': 'SL Malinga',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {0.4: {'batsman': 'M Klinger',
#       'bowler': 'SL Malinga',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {0.5: {'batsman': 'M Klinger',
#       'bowler': 'SL Malinga',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {0.6: {'batsman': 'M Klinger',
#       'bowler': 'SL Malinga',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#     {1.1: {'batsman': 'M Klinger',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {1.2: {'batsman': 'M Klinger',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {1.3: {'batsman': 'AJ Finch',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {1.4: {'batsman': 'AJ Finch',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {1.5: {'batsman': 'AJ Finch',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {1.6: {'batsman': 'AJ Finch',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {2.1: {'batsman': 'M Klinger',
#       'bowler': 'JRMVB Sanjaya',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {2.2: {'batsman': 'AJ Finch',
#       'bowler': 'JRMVB Sanjaya',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {2.3: {'batsman': 'M Klinger',
#       'bowler': 'JRMVB Sanjaya',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {2.4: {'batsman': 'M Klinger',
#       'bowler': 'JRMVB Sanjaya',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {2.5: {'batsman': 'M Klinger',
#       'bowler': 'JRMVB Sanjaya',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {2.6: {'batsman': 'M Klinger',
#       'bowler': 'JRMVB Sanjaya',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {3.1: {'batsman': 'AJ Finch',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {3.2: {'batsman': 'AJ Finch',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {3.3: {'batsman': 'M Klinger',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {3.4: {'batsman': 'AJ Finch',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {3.5: {'batsman': 'M Klinger',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {3.6: {'batsman': 'M Klinger',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {4.1: {'batsman': 'M Klinger',
#       'bowler': 'JRMVB Sanjaya',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#     {4.2: {'batsman': 'AJ Finch',
#       'bowler': 'JRMVB Sanjaya',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#     {4.3: {'batsman': 'M Klinger',
#       'bowler': 'JRMVB Sanjaya',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {4.4: {'batsman': 'M Klinger',
#       'bowler': 'JRMVB Sanjaya',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {4.5: {'batsman': 'M Klinger',
#       'bowler': 'JRMVB Sanjaya',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {4.6: {'batsman': 'AJ Finch',
#       'bowler': 'JRMVB Sanjaya',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {5.1: {'batsman': 'AJ Finch',
#       'bowler': 'S Prasanna',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {5.2: {'batsman': 'M Klinger',
#       'bowler': 'S Prasanna',
#       'extras': {'wides': 1},
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {5.3: {'batsman': 'M Klinger',
#       'bowler': 'S Prasanna',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {5.4: {'batsman': 'M Klinger',
#       'bowler': 'S Prasanna',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {5.5: {'batsman': 'M Klinger',
#       'bowler': 'S Prasanna',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {5.6: {'batsman': 'AJ Finch',
#       'bowler': 'S Prasanna',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {5.7: {'batsman': 'M Klinger',
#       'bowler': 'S Prasanna',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {6.1: {'batsman': 'AJ Finch',
#       'bowler': 'PADLR Sandakan',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {6.2: {'batsman': 'M Klinger',
#       'bowler': 'PADLR Sandakan',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {6.3: {'batsman': 'AJ Finch',
#       'bowler': 'PADLR Sandakan',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {6.4: {'batsman': 'AJ Finch',
#       'bowler': 'PADLR Sandakan',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {6.5: {'batsman': 'M Klinger',
#       'bowler': 'PADLR Sandakan',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {6.6: {'batsman': 'AJ Finch',
#       'bowler': 'PADLR Sandakan',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {7.1: {'batsman': 'M Klinger',
#       'bowler': 'S Prasanna',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {7.2: {'batsman': 'M Klinger',
#       'bowler': 'S Prasanna',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {7.3: {'batsman': 'AJ Finch',
#       'bowler': 'S Prasanna',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {7.4: {'batsman': 'M Klinger',
#       'bowler': 'S Prasanna',
#       'extras': {'byes': 1},
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {7.5: {'batsman': 'AJ Finch',
#       'bowler': 'S Prasanna',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {7.6: {'batsman': 'AJ Finch',
#       'bowler': 'S Prasanna',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {8.1: {'batsman': 'AJ Finch',
#       'bowler': 'PADLR Sandakan',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {8.2: {'batsman': 'M Klinger',
#       'bowler': 'PADLR Sandakan',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#     {8.3: {'batsman': 'AJ Finch',
#       'bowler': 'PADLR Sandakan',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {8.4: {'batsman': 'M Klinger',
#       'bowler': 'PADLR Sandakan',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {8.5: {'batsman': 'M Klinger',
#       'bowler': 'PADLR Sandakan',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {8.6: {'batsman': 'M Klinger',
#       'bowler': 'PADLR Sandakan',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {9.1: {'batsman': 'M Klinger',
#       'bowler': 'S Prasanna',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {9.2: {'batsman': 'AJ Finch',
#       'bowler': 'S Prasanna',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {9.3: {'batsman': 'AJ Finch',
#       'bowler': 'S Prasanna',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {9.4: {'batsman': 'AJ Finch',
#       'bowler': 'S Prasanna',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {9.5: {'batsman': 'AJ Finch',
#       'bowler': 'S Prasanna',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#     {9.6: {'batsman': 'AJ Finch',
#       'bowler': 'S Prasanna',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {10.1: {'batsman': 'AJ Finch',
#       'bowler': 'PADLR Sandakan',
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {10.2: {'batsman': 'AJ Finch',
#       'bowler': 'PADLR Sandakan',
#       'extras': {'legbyes': 1},
#       'non_striker': 'M Klinger',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {10.3: {'batsman': 'M Klinger',
#       'bowler': 'PADLR Sandakan',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'fielders': ['SL Malinga'],
#        'kind': 'caught',
#        'player_out': 'M Klinger'}}},
#     {10.4: {'batsman': 'TM Head',
#       'bowler': 'PADLR Sandakan',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {10.5: {'batsman': 'TM Head',
#       'bowler': 'PADLR Sandakan',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {10.6: {'batsman': 'TM Head',
#       'bowler': 'PADLR Sandakan',
#       'non_striker': 'AJ Finch',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {11.1: {'batsman': 'AJ Finch',
#       'bowler': 'DAS Gunaratne',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#     {11.2: {'batsman': 'AJ Finch',
#       'bowler': 'DAS Gunaratne',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {11.3: {'batsman': 'AJ Finch',
#       'bowler': 'DAS Gunaratne',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'fielders': ['SL Malinga'],
#        'kind': 'caught',
#        'player_out': 'AJ Finch'}}},
#     {11.4: {'batsman': 'TM Head',
#       'bowler': 'DAS Gunaratne',
#       'non_striker': 'MC Henriques',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {11.5: {'batsman': 'MC Henriques',
#       'bowler': 'DAS Gunaratne',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {11.6: {'batsman': 'TM Head',
#       'bowler': 'DAS Gunaratne',
#       'non_striker': 'MC Henriques',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {12.1: {'batsman': 'TM Head',
#       'bowler': 'S Prasanna',
#       'non_striker': 'MC Henriques',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {12.2: {'batsman': 'TM Head',
#       'bowler': 'S Prasanna',
#       'non_striker': 'MC Henriques',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {12.3: {'batsman': 'MC Henriques',
#       'bowler': 'S Prasanna',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {12.4: {'batsman': 'TM Head',
#       'bowler': 'S Prasanna',
#       'non_striker': 'MC Henriques',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {12.5: {'batsman': 'TM Head',
#       'bowler': 'S Prasanna',
#       'non_striker': 'MC Henriques',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {12.6: {'batsman': 'MC Henriques',
#       'bowler': 'S Prasanna',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {13.1: {'batsman': 'MC Henriques',
#       'bowler': 'SL Malinga',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {13.2: {'batsman': 'MC Henriques',
#       'bowler': 'SL Malinga',
#       'extras': {'wides': 1},
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {13.3: {'batsman': 'MC Henriques',
#       'bowler': 'SL Malinga',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {13.4: {'batsman': 'TM Head',
#       'bowler': 'SL Malinga',
#       'non_striker': 'MC Henriques',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {13.5: {'batsman': 'TM Head',
#       'bowler': 'SL Malinga',
#       'non_striker': 'MC Henriques',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {13.6: {'batsman': 'MC Henriques',
#       'bowler': 'SL Malinga',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {13.7: {'batsman': 'TM Head',
#       'bowler': 'SL Malinga',
#       'non_striker': 'MC Henriques',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {14.1: {'batsman': 'TM Head',
#       'bowler': 'PADLR Sandakan',
#       'non_striker': 'MC Henriques',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {14.2: {'batsman': 'MC Henriques',
#       'bowler': 'PADLR Sandakan',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#     {14.3: {'batsman': 'TM Head',
#       'bowler': 'PADLR Sandakan',
#       'non_striker': 'MC Henriques',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {14.4: {'batsman': 'MC Henriques',
#       'bowler': 'PADLR Sandakan',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#     {14.5: {'batsman': 'MC Henriques',
#       'bowler': 'PADLR Sandakan',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#     {14.6: {'batsman': 'TM Head',
#       'bowler': 'PADLR Sandakan',
#       'non_striker': 'MC Henriques',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {15.1: {'batsman': 'MC Henriques',
#       'bowler': 'JRMVB Sanjaya',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'fielders': ['CK Kapugedera'],
#        'kind': 'caught',
#        'player_out': 'MC Henriques'}}},
#     {15.2: {'batsman': 'TM Head',
#       'bowler': 'JRMVB Sanjaya',
#       'non_striker': 'AJ Turner',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {15.3: {'batsman': 'AJ Turner',
#       'bowler': 'JRMVB Sanjaya',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {15.4: {'batsman': 'AJ Turner',
#       'bowler': 'JRMVB Sanjaya',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {15.5: {'batsman': 'TM Head',
#       'bowler': 'JRMVB Sanjaya',
#       'non_striker': 'AJ Turner',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {15.6: {'batsman': 'TM Head',
#       'bowler': 'JRMVB Sanjaya',
#       'extras': {'wides': 1},
#       'non_striker': 'AJ Turner',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {15.7: {'batsman': 'TM Head',
#       'bowler': 'JRMVB Sanjaya',
#       'non_striker': 'AJ Turner',
#       'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#     {16.1: {'batsman': 'AJ Turner',
#       'bowler': 'SL Malinga',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {16.2: {'batsman': 'AJ Turner',
#       'bowler': 'SL Malinga',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {16.3: {'batsman': 'AJ Turner',
#       'bowler': 'SL Malinga',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {16.4: {'batsman': 'TM Head',
#       'bowler': 'SL Malinga',
#       'non_striker': 'AJ Turner',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {16.5: {'batsman': 'AJ Turner',
#       'bowler': 'SL Malinga',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {16.6: {'batsman': 'TM Head',
#       'bowler': 'SL Malinga',
#       'non_striker': 'AJ Turner',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {17.1: {'batsman': 'TM Head',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'AJ Turner',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {17.2: {'batsman': 'AJ Turner',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {17.3: {'batsman': 'AJ Turner',
#       'bowler': 'KMDN Kulasekara',
#       'extras': {'noballs': 1},
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {17.4: {'batsman': 'AJ Turner',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {17.5: {'batsman': 'TM Head',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'AJ Turner',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {17.6: {'batsman': 'AJ Turner',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {17.7: {'batsman': 'TM Head',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'AJ Turner',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {18.1: {'batsman': 'AJ Turner',
#       'bowler': 'SL Malinga',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {18.2: {'batsman': 'AJ Turner',
#       'bowler': 'SL Malinga',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {18.3: {'batsman': 'TM Head',
#       'bowler': 'SL Malinga',
#       'non_striker': 'AJ Turner',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {18.4: {'batsman': 'TM Head',
#       'bowler': 'SL Malinga',
#       'non_striker': 'AJ Turner',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'fielders': ['S Prasanna'],
#        'kind': 'caught',
#        'player_out': 'TM Head'}}},
#     {18.5: {'batsman': 'AJ Turner',
#       'bowler': 'SL Malinga',
#       'non_striker': 'JP Faulkner',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'fielders': ['S Prasanna'],
#        'kind': 'caught',
#        'player_out': 'AJ Turner'}}},
#     {18.6: {'batsman': 'JP Faulkner',
#       'bowler': 'SL Malinga',
#       'non_striker': 'TD Paine',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {19.1: {'batsman': 'JP Faulkner',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'TD Paine',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {19.2: {'batsman': 'JP Faulkner',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'TD Paine',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {19.3: {'batsman': 'JP Faulkner',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'TD Paine',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {19.4: {'batsman': 'JP Faulkner',
#       'bowler': 'KMDN Kulasekara',
#       'extras': {'wides': 1},
#       'non_striker': 'TD Paine',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {19.5: {'batsman': 'JP Faulkner',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'TD Paine',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1},
#       'wicket': {'fielders': ['CK Kapugedera', 'KMDN Kulasekara'],
#        'kind': 'run out',
#        'player_out': 'TD Paine'}}},
#     {19.6: {'batsman': 'JP Faulkner',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'PJ Cummins',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {19.7: {'batsman': 'JP Faulkner',
#       'bowler': 'KMDN Kulasekara',
#       'non_striker': 'PJ Cummins',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}]}},
#  {'2nd innings': {'team': 'Sri Lanka',
#    'deliveries': [{0.1: {'batsman': 'N Dickwella',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'WU Tharanga',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {0.2: {'batsman': 'WU Tharanga',
#       'bowler': 'PJ Cummins',
#       'extras': {'legbyes': 1},
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {0.3: {'batsman': 'N Dickwella',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'WU Tharanga',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {0.4: {'batsman': 'N Dickwella',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'WU Tharanga',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {0.5: {'batsman': 'N Dickwella',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'WU Tharanga',
#       'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#     {0.6: {'batsman': 'WU Tharanga',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'fielders': ['TD Paine'],
#        'kind': 'caught',
#        'player_out': 'WU Tharanga'}}},
#     {1.1: {'batsman': 'N Dickwella',
#       'bowler': 'B Stanlake',
#       'extras': {'wides': 1},
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {1.2: {'batsman': 'N Dickwella',
#       'bowler': 'B Stanlake',
#       'extras': {'wides': 1},
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {1.3: {'batsman': 'N Dickwella',
#       'bowler': 'B Stanlake',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {1.4: {'batsman': 'N Dickwella',
#       'bowler': 'B Stanlake',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {1.5: {'batsman': 'N Dickwella',
#       'bowler': 'B Stanlake',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {1.6: {'batsman': 'N Dickwella',
#       'bowler': 'B Stanlake',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {1.7: {'batsman': 'N Dickwella',
#       'bowler': 'B Stanlake',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {1.8: {'batsman': 'N Dickwella',
#       'bowler': 'B Stanlake',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {2.1: {'batsman': 'EMDY Munaweera',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {2.2: {'batsman': 'EMDY Munaweera',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#     {2.3: {'batsman': 'N Dickwella',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {2.4: {'batsman': 'N Dickwella',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {2.5: {'batsman': 'N Dickwella',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {2.6: {'batsman': 'N Dickwella',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {3.1: {'batsman': 'EMDY Munaweera',
#       'bowler': 'B Stanlake',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {3.2: {'batsman': 'EMDY Munaweera',
#       'bowler': 'B Stanlake',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {3.3: {'batsman': 'EMDY Munaweera',
#       'bowler': 'B Stanlake',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {3.4: {'batsman': 'EMDY Munaweera',
#       'bowler': 'B Stanlake',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {3.5: {'batsman': 'N Dickwella',
#       'bowler': 'B Stanlake',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {3.6: {'batsman': 'N Dickwella',
#       'bowler': 'B Stanlake',
#       'extras': {'wides': 5},
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 0, 'extras': 5, 'total': 5}}},
#     {3.7: {'batsman': 'N Dickwella',
#       'bowler': 'B Stanlake',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#     {4.1: {'batsman': 'EMDY Munaweera',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {4.2: {'batsman': 'EMDY Munaweera',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {4.3: {'batsman': 'EMDY Munaweera',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {4.4: {'batsman': 'EMDY Munaweera',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {4.5: {'batsman': 'EMDY Munaweera',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {4.6: {'batsman': 'N Dickwella',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {5.1: {'batsman': 'EMDY Munaweera',
#       'bowler': 'AJ Tye',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {5.2: {'batsman': 'EMDY Munaweera',
#       'bowler': 'AJ Tye',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {5.3: {'batsman': 'EMDY Munaweera',
#       'bowler': 'AJ Tye',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {5.4: {'batsman': 'EMDY Munaweera',
#       'bowler': 'AJ Tye',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {5.5: {'batsman': 'EMDY Munaweera',
#       'bowler': 'AJ Tye',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {5.6: {'batsman': 'EMDY Munaweera',
#       'bowler': 'AJ Tye',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {6.1: {'batsman': 'EMDY Munaweera',
#       'bowler': 'A Zampa',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {6.2: {'batsman': 'N Dickwella',
#       'bowler': 'A Zampa',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {6.3: {'batsman': 'N Dickwella',
#       'bowler': 'A Zampa',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {6.4: {'batsman': 'EMDY Munaweera',
#       'bowler': 'A Zampa',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {6.5: {'batsman': 'EMDY Munaweera',
#       'bowler': 'A Zampa',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {6.6: {'batsman': 'EMDY Munaweera',
#       'bowler': 'A Zampa',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {7.1: {'batsman': 'EMDY Munaweera',
#       'bowler': 'AJ Turner',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {7.2: {'batsman': 'EMDY Munaweera',
#       'bowler': 'AJ Turner',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {7.3: {'batsman': 'N Dickwella',
#       'bowler': 'AJ Turner',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {7.4: {'batsman': 'N Dickwella',
#       'bowler': 'AJ Turner',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {7.5: {'batsman': 'EMDY Munaweera',
#       'bowler': 'AJ Turner',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {7.6: {'batsman': 'N Dickwella',
#       'bowler': 'AJ Turner',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {8.1: {'batsman': 'N Dickwella',
#       'bowler': 'A Zampa',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {8.2: {'batsman': 'EMDY Munaweera',
#       'bowler': 'A Zampa',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {8.3: {'batsman': 'EMDY Munaweera',
#       'bowler': 'A Zampa',
#       'non_striker': 'N Dickwella',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {8.4: {'batsman': 'N Dickwella',
#       'bowler': 'A Zampa',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {8.5: {'batsman': 'N Dickwella',
#       'bowler': 'A Zampa',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'fielders': ['M Klinger'],
#        'kind': 'caught',
#        'player_out': 'N Dickwella'}}},
#     {8.6: {'batsman': 'DAS Gunaratne',
#       'bowler': 'A Zampa',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {9.1: {'batsman': 'DAS Gunaratne',
#       'bowler': 'B Stanlake',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {9.2: {'batsman': 'DAS Gunaratne',
#       'bowler': 'B Stanlake',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {9.3: {'batsman': 'DAS Gunaratne',
#       'bowler': 'B Stanlake',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {9.4: {'batsman': 'EMDY Munaweera',
#       'bowler': 'B Stanlake',
#       'non_striker': 'DAS Gunaratne',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {9.5: {'batsman': 'DAS Gunaratne',
#       'bowler': 'B Stanlake',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {9.6: {'batsman': 'DAS Gunaratne',
#       'bowler': 'B Stanlake',
#       'extras': {'wides': 1},
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {9.7: {'batsman': 'DAS Gunaratne',
#       'bowler': 'B Stanlake',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {10.1: {'batsman': 'DAS Gunaratne',
#       'bowler': 'A Zampa',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {10.2: {'batsman': 'DAS Gunaratne',
#       'bowler': 'A Zampa',
#       'non_striker': 'EMDY Munaweera',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {10.3: {'batsman': 'EMDY Munaweera',
#       'bowler': 'A Zampa',
#       'non_striker': 'DAS Gunaratne',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {10.4: {'batsman': 'EMDY Munaweera',
#       'bowler': 'A Zampa',
#       'non_striker': 'DAS Gunaratne',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'fielders': ['AJ Finch'],
#        'kind': 'caught',
#        'player_out': 'EMDY Munaweera'}}},
#     {10.5: {'batsman': 'TAM Siriwardana',
#       'bowler': 'A Zampa',
#       'non_striker': 'DAS Gunaratne',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {10.6: {'batsman': 'DAS Gunaratne',
#       'bowler': 'A Zampa',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {11.1: {'batsman': 'DAS Gunaratne',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {11.2: {'batsman': 'DAS Gunaratne',
#       'bowler': 'JP Faulkner',
#       'extras': {'legbyes': 1},
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {11.3: {'batsman': 'TAM Siriwardana',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'DAS Gunaratne',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {11.4: {'batsman': 'DAS Gunaratne',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {11.5: {'batsman': 'TAM Siriwardana',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'DAS Gunaratne',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {11.6: {'batsman': 'DAS Gunaratne',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {12.1: {'batsman': 'DAS Gunaratne',
#       'bowler': 'A Zampa',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {12.2: {'batsman': 'TAM Siriwardana',
#       'bowler': 'A Zampa',
#       'non_striker': 'DAS Gunaratne',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {12.3: {'batsman': 'TAM Siriwardana',
#       'bowler': 'A Zampa',
#       'non_striker': 'DAS Gunaratne',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {12.4: {'batsman': 'DAS Gunaratne',
#       'bowler': 'A Zampa',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {12.5: {'batsman': 'TAM Siriwardana',
#       'bowler': 'A Zampa',
#       'non_striker': 'DAS Gunaratne',
#       'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#     {12.6: {'batsman': 'DAS Gunaratne',
#       'bowler': 'A Zampa',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {13.1: {'batsman': 'DAS Gunaratne',
#       'bowler': 'AJ Tye',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {13.2: {'batsman': 'DAS Gunaratne',
#       'bowler': 'AJ Tye',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {13.3: {'batsman': 'DAS Gunaratne',
#       'bowler': 'AJ Tye',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {13.4: {'batsman': 'DAS Gunaratne',
#       'bowler': 'AJ Tye',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {13.5: {'batsman': 'TAM Siriwardana',
#       'bowler': 'AJ Tye',
#       'non_striker': 'DAS Gunaratne',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {13.6: {'batsman': 'TAM Siriwardana',
#       'bowler': 'AJ Tye',
#       'non_striker': 'DAS Gunaratne',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {14.1: {'batsman': 'DAS Gunaratne',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {14.2: {'batsman': 'TAM Siriwardana',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'DAS Gunaratne',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {14.3: {'batsman': 'DAS Gunaratne',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {14.4: {'batsman': 'DAS Gunaratne',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {14.5: {'batsman': 'DAS Gunaratne',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {14.6: {'batsman': 'DAS Gunaratne',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {15.1: {'batsman': 'DAS Gunaratne',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {15.2: {'batsman': 'DAS Gunaratne',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {15.3: {'batsman': 'DAS Gunaratne',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {15.4: {'batsman': 'DAS Gunaratne',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {15.5: {'batsman': 'DAS Gunaratne',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {15.6: {'batsman': 'DAS Gunaratne',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {16.1: {'batsman': 'DAS Gunaratne',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {16.2: {'batsman': 'DAS Gunaratne',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {16.3: {'batsman': 'DAS Gunaratne',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {16.4: {'batsman': 'DAS Gunaratne',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {16.5: {'batsman': 'TAM Siriwardana',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'DAS Gunaratne',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {16.6: {'batsman': 'DAS Gunaratne',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {17.1: {'batsman': 'DAS Gunaratne',
#       'bowler': 'AJ Turner',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'fielders': ['TD Paine'],
#        'kind': 'stumped',
#        'player_out': 'DAS Gunaratne'}}},
#     {17.2: {'batsman': 'CK Kapugedera',
#       'bowler': 'AJ Turner',
#       'non_striker': 'TAM Siriwardana',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {17.3: {'batsman': 'TAM Siriwardana',
#       'bowler': 'AJ Turner',
#       'non_striker': 'CK Kapugedera',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'kind': 'lbw', 'player_out': 'TAM Siriwardana'}}},
#     {17.4: {'batsman': 'S Prasanna',
#       'bowler': 'AJ Turner',
#       'non_striker': 'CK Kapugedera',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {17.5: {'batsman': 'S Prasanna',
#       'bowler': 'AJ Turner',
#       'non_striker': 'CK Kapugedera',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {17.6: {'batsman': 'S Prasanna',
#       'bowler': 'AJ Turner',
#       'non_striker': 'CK Kapugedera',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {18.1: {'batsman': 'S Prasanna',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'CK Kapugedera',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {18.2: {'batsman': 'CK Kapugedera',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'S Prasanna',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {18.3: {'batsman': 'S Prasanna',
#       'bowler': 'JP Faulkner',
#       'extras': {'wides': 1},
#       'non_striker': 'CK Kapugedera',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {18.4: {'batsman': 'S Prasanna',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'CK Kapugedera',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {18.5: {'batsman': 'CK Kapugedera',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'S Prasanna',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {18.6: {'batsman': 'CK Kapugedera',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'S Prasanna',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {18.7: {'batsman': 'S Prasanna',
#       'bowler': 'JP Faulkner',
#       'extras': {'legbyes': 1},
#       'non_striker': 'CK Kapugedera',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {19.1: {'batsman': 'S Prasanna',
#       'bowler': 'AJ Tye',
#       'non_striker': 'CK Kapugedera',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {19.2: {'batsman': 'S Prasanna',
#       'bowler': 'AJ Tye',
#       'extras': {'byes': 1},
#       'non_striker': 'CK Kapugedera',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {19.3: {'batsman': 'CK Kapugedera',
#       'bowler': 'AJ Tye',
#       'non_striker': 'S Prasanna',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {19.4: {'batsman': 'S Prasanna',
#       'bowler': 'AJ Tye',
#       'non_striker': 'CK Kapugedera',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {19.5: {'batsman': 'CK Kapugedera',
#       'bowler': 'AJ Tye',
#       'non_striker': 'S Prasanna',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {19.6: {'batsman': 'CK Kapugedera',
#       'bowler': 'AJ Tye',
#       'non_striker': 'S Prasanna',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}]}}]

# %%
import ast
count = 1
delivery_df = pd.DataFrame()
# matches = final_df.copy()
for index, row in matches.iterrows():
    # if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
    #     count+=1
    #     continue
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    row_innings = ast.literal_eval(row['innings'])
    # row_innings = row['innings']
    for ball in row_innings[0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row_innings[0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df = pd.concat([delivery_df, loop_df], ignore_index=True)

# %%
delivery_df
# Out:
#         match_id                       teams batting_team  ball  \
# 0              2  ['Australia', 'Sri Lanka']    Australia   0.1
# 1              2  ['Australia', 'Sri Lanka']    Australia   0.2
# 2              2  ['Australia', 'Sri Lanka']    Australia   0.3
# 3              2  ['Australia', 'Sri Lanka']    Australia   0.4
# 4              2  ['Australia', 'Sri Lanka']    Australia   0.5
# ...          ...                         ...          ...   ...
# 199143      1647  ['Sri Lanka', 'Australia']    Sri Lanka  19.3
# 199144      1647  ['Sri Lanka', 'Australia']    Sri Lanka  19.4
# 199145      1647  ['Sri Lanka', 'Australia']    Sri Lanka  19.5
# 199146      1647  ['Sri Lanka', 'Australia']    Sri Lanka  19.6
# 199147      1647  ['Sri Lanka', 'Australia']    Sri Lanka  19.7
#
#                 batsman      bowler  runs player_dismissed     city  \
# 0              AJ Finch  SL Malinga     0                0      NaN
# 1              AJ Finch  SL Malinga     0                0      NaN
# 2              AJ Finch  SL Malinga     1                0      NaN
# 3             M Klinger  SL Malinga     2                0      NaN
# 4             M Klinger  SL Malinga     0                0      NaN
# ...                 ...         ...   ...              ...      ...
# 199143  SMSM Senanayake    MA Starc     1                0  Colombo
# 199144      DM de Silva    MA Starc     0                0  Colombo
# 199145      DM de Silva    MA Starc     0      DM de Silva  Colombo
# 199146  SMSM Senanayake    MA Starc     2                0  Colombo
# 199147  SMSM Senanayake    MA Starc     1                0  Colombo
#
#                            venue
# 0       Melbourne Cricket Ground
# 1       Melbourne Cricket Ground
# 2       Melbourne Cricket Ground
# 3       Melbourne Cricket Ground
# 4       Melbourne Cricket Ground
# ...                          ...
# 199143       R Premadasa Stadium
# 199144       R Premadasa Stadium
# 199145       R Premadasa Stadium
# 199146       R Premadasa Stadium
# 199147       R Premadasa Stadium
#
# [199148 rows x 10 columns]

# %%
def bowl(row):
    row_teams = ast.literal_eval(row['teams'])
    for team in row_teams:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df
# Out:
#         match_id                       teams batting_team  ball  \
# 0              2  ['Australia', 'Sri Lanka']    Australia   0.1
# 1              2  ['Australia', 'Sri Lanka']    Australia   0.2
# 2              2  ['Australia', 'Sri Lanka']    Australia   0.3
# 3              2  ['Australia', 'Sri Lanka']    Australia   0.4
# 4              2  ['Australia', 'Sri Lanka']    Australia   0.5
# ...          ...                         ...          ...   ...
# 199143      1647  ['Sri Lanka', 'Australia']    Sri Lanka  19.3
# 199144      1647  ['Sri Lanka', 'Australia']    Sri Lanka  19.4
# 199145      1647  ['Sri Lanka', 'Australia']    Sri Lanka  19.5
# 199146      1647  ['Sri Lanka', 'Australia']    Sri Lanka  19.6
# 199147      1647  ['Sri Lanka', 'Australia']    Sri Lanka  19.7
#
#                 batsman      bowler  runs player_dismissed     city  \
# 0              AJ Finch  SL Malinga     0                0      NaN
# 1              AJ Finch  SL Malinga     0                0      NaN
# 2              AJ Finch  SL Malinga     1                0      NaN
# 3             M Klinger  SL Malinga     2                0      NaN
# 4             M Klinger  SL Malinga     0                0      NaN
# ...                 ...         ...   ...              ...      ...
# 199143  SMSM Senanayake    MA Starc     1                0  Colombo
# 199144      DM de Silva    MA Starc     0                0  Colombo
# 199145      DM de Silva    MA Starc     0      DM de Silva  Colombo
# 199146  SMSM Senanayake    MA Starc     2                0  Colombo
# 199147  SMSM Senanayake    MA Starc     1                0  Colombo
#
#                            venue bowling_team
# 0       Melbourne Cricket Ground    Sri Lanka
# 1       Melbourne Cricket Ground    Sri Lanka
# 2       Melbourne Cricket Ground    Sri Lanka
# 3       Melbourne Cricket Ground    Sri Lanka
# 4       Melbourne Cricket Ground    Sri Lanka
# ...                          ...          ...
# 199143       R Premadasa Stadium    Australia
# 199144       R Premadasa Stadium    Australia
# 199145       R Premadasa Stadium    Australia
# 199146       R Premadasa Stadium    Australia
# 199147       R Premadasa Stadium    Australia
#
# [199148 rows x 11 columns]

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['Australia', 'Hong Kong', 'Zimbabwe', 'India', 'Bangladesh',
#        'New Zealand', 'South Africa', 'England', 'West Indies',
#        'Pakistan', 'Scotland', 'Oman', 'Ireland', 'Papua New Guinea',
#        'United Arab Emirates', 'Sri Lanka', 'Netherlands', 'Nepal',
#        'Vanuatu', 'Philippines', 'United States of America', 'Germany',
#        'Ghana', 'Uganda', 'Kenya', 'Namibia', 'Nigeria', 'Botswana',
#        'Guernsey', 'Denmark', 'Jersey', 'Italy', 'Norway', 'Thailand',
#        'Malaysia', 'Maldives', 'Singapore', 'Kuwait', 'Bermuda', 'Canada',
#        'Cayman Islands', 'Portugal', 'Gibraltar', 'Spain', 'Bhutan',
#        'Qatar', 'Iran', 'Belgium', 'Isle of Man', 'Bulgaria', 'Romania',
#        'Luxembourg', 'Austria', 'Czech Republic', 'Greece', 'Serbia',
#        'Malta', 'France', 'Sweden', 'Rwanda', 'Finland', 'Hungary',
#        'Estonia', 'Cyprus', 'Switzerland', 'Seychelles', 'Malawi',
#        'Lesotho', 'Swaziland', 'Tanzania', 'Mozambique', 'Sierra Leone',
#        'Cameroon', 'Bahrain', 'Belize', 'Bahamas', 'Argentina', 'Panama',
#        'Israel', 'Croatia', 'Turkey', 'Slovenia', 'Cook Islands', 'Samoa',
#        'Fiji', 'Japan', 'Indonesia', 'South Korea', 'Mali', 'St Helena',
#        'Gambia', 'Eswatini', 'Saudi Arabia'], dtype=object)

# %%
'Afghanistan' in delivery_df['batting_team'].unique()
# Out:
# False

# %%
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Pakistan',
    'Sri Lanka'    
]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#         match_id batting_team  ball          batsman      bowler  runs  \
# 0              2    Australia   0.1         AJ Finch  SL Malinga     0
# 1              2    Australia   0.2         AJ Finch  SL Malinga     0
# 2              2    Australia   0.3         AJ Finch  SL Malinga     1
# 3              2    Australia   0.4        M Klinger  SL Malinga     2
# 4              2    Australia   0.5        M Klinger  SL Malinga     0
# ...          ...          ...   ...              ...         ...   ...
# 199143      1647    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 199144      1647    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 199145      1647    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 199146      1647    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 199147      1647    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
#        player_dismissed     city                     venue bowling_team
# 0                     0      NaN  Melbourne Cricket Ground    Sri Lanka
# 1                     0      NaN  Melbourne Cricket Ground    Sri Lanka
# 2                     0      NaN  Melbourne Cricket Ground    Sri Lanka
# 3                     0      NaN  Melbourne Cricket Ground    Sri Lanka
# 4                     0      NaN  Melbourne Cricket Ground    Sri Lanka
# ...                 ...      ...                       ...          ...
# 199143                0  Colombo       R Premadasa Stadium    Australia
# 199144                0  Colombo       R Premadasa Stadium    Australia
# 199145      DM de Silva  Colombo       R Premadasa Stadium    Australia
# 199146                0  Colombo       R Premadasa Stadium    Australia
# 199147                0  Colombo       R Premadasa Stadium    Australia
#
# [86407 rows x 10 columns]

# %%
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
output
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 199143      1647    Sri Lanka    Australia  19.3     1                0
# 199144      1647    Sri Lanka    Australia  19.4     0                0
# 199145      1647    Sri Lanka    Australia  19.5     0      DM de Silva
# 199146      1647    Sri Lanka    Australia  19.6     2                0
# 199147      1647    Sri Lanka    Australia  19.7     1                0
#
#            city                     venue
# 0           NaN  Melbourne Cricket Ground
# 1           NaN  Melbourne Cricket Ground
# 2           NaN  Melbourne Cricket Ground
# 3           NaN  Melbourne Cricket Ground
# 4           NaN  Melbourne Cricket Ground
# ...         ...                       ...
# 199143  Colombo       R Premadasa Stadium
# 199144  Colombo       R Premadasa Stadium
# 199145  Colombo       R Premadasa Stadium
# 199146  Colombo       R Premadasa Stadium
# 199147  Colombo       R Premadasa Stadium
#
# [86407 rows x 8 columns]

# %%
output.to_csv('dataset_level2.csv', index=False)

# %%
# batting team
# bowling team
# city
# current score
# balls left
# wickets left
# current run rate
# runs in last five overs

# %%
output.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8549
# venue                  0
# dtype: int64

# %%
output[output['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium        3092
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sylhet International Cricket Stadium        128
# Sharjah Cricket Stadium                     127
# Carrara Oval                                 64
# Name: count, dtype: int64

# %%
x = np.where(output['city'].isnull(), output['venue'].str.split().apply(lambda x:x[0]), output['city'])

# %%
output['city'] = x
# Out:
# C:\Users\srika\AppData\Local\Temp\ipykernel_33196\2208188131.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output['city'] = x

# %%
output.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
output.drop(columns=['venue'],inplace=True)
# Out:
# C:\Users\srika\AppData\Local\Temp\ipykernel_33196\2962604362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output.drop(columns=['venue'],inplace=True)

# %%
output
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 199143      1647    Sri Lanka    Australia  19.3     1                0
# 199144      1647    Sri Lanka    Australia  19.4     0                0
# 199145      1647    Sri Lanka    Australia  19.5     0      DM de Silva
# 199146      1647    Sri Lanka    Australia  19.6     2                0
# 199147      1647    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# 4       Melbourne
# ...           ...
# 199143    Colombo
# 199144    Colombo
# 199145    Colombo
# 199146    Colombo
# 199147    Colombo
#
# [86407 rows x 7 columns]

# %%
output['city'].value_counts()
# Out:
# city
# Colombo          4924
# Dubai            4889
# Johannesburg     3706
# Mirpur           3190
# Auckland         2845
#                  ...
# Jamaica           125
# Victoria          123
# Nairobi           123
# Jaipur            123
# Potchefstroom     122
# Name: count, Length: 97, dtype: int64

# %%
eligible_cities = output['city'].value_counts()[output['city'].value_counts() > 600].index.tolist()

# %%
output = output[output['city'].isin(eligible_cities)]

# %%
output.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 71956 entries, 0 to 199147
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_id          71956 non-null  int64
#  1   batting_team      71956 non-null  object
#  2   bowling_team      71956 non-null  object
#  3   ball              71956 non-null  float64
#  4   runs              71956 non-null  int64
#  5   player_dismissed  71956 non-null  object
#  6   city              71956 non-null  object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 4.4+ MB

# %%
output['current_score'] = output.groupby('match_id')['runs'].cumsum()
# Out:
# C:\Users\srika\AppData\Local\Temp\ipykernel_33196\1948576997.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output['current_score'] = output.groupby('match_id')['runs'].cumsum()

# %%
output.tail(120)
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 199028      1647    Sri Lanka    Australia   0.7     0                0
# 199029      1647    Sri Lanka    Australia   1.1     0                0
# 199030      1647    Sri Lanka    Australia   1.2     0       TM Dilshan
# 199031      1647    Sri Lanka    Australia   1.3     0                0
# 199032      1647    Sri Lanka    Australia   1.4     0                0
# ...          ...          ...          ...   ...   ...              ...
# 199143      1647    Sri Lanka    Australia  19.3     1                0
# 199144      1647    Sri Lanka    Australia  19.4     0                0
# 199145      1647    Sri Lanka    Australia  19.5     0      DM de Silva
# 199146      1647    Sri Lanka    Australia  19.6     2                0
# 199147      1647    Sri Lanka    Australia  19.7     1                0
#
#            city  current_score
# 199028  Colombo              9
# 199029  Colombo              9
# 199030  Colombo              9
# 199031  Colombo              9
# 199032  Colombo              9
# ...         ...            ...
# 199143  Colombo            125
# 199144  Colombo            125
# 199145  Colombo            125
# 199146  Colombo            127
# 199147  Colombo            128
#
# [120 rows x 8 columns]

# %%
output['over'] = output['ball'].apply(lambda x:str(x).split(".")[0])
output['ball_no'] = output['ball'].apply(lambda x:str(x).split(".")[1])
# Out:
# C:\Users\srika\AppData\Local\Temp\ipykernel_33196\2016172815.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output['over'] = output['ball'].apply(lambda x:str(x).split(".")[0])
# C:\Users\srika\AppData\Local\Temp\ipykernel_33196\2016172815.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output['ball_no'] = output['ball'].apply(lambda x:str(x).split(".")[1])

# %%
output['balls_bowled'] = (output['over'].astype('int')*6) + output['ball_no'].astype('int')
# Out:
# C:\Users\srika\AppData\Local\Temp\ipykernel_33196\765384734.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output['balls_bowled'] = (output['over'].astype('int')*6) + output['ball_no'].astype('int')

# %%
output['balls_left'] = 120 - output['balls_bowled']
output['balls_left'] = output['balls_left'].apply(lambda x:0 if x<0 else x)
# Out:
# C:\Users\srika\AppData\Local\Temp\ipykernel_33196\5402639.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output['balls_left'] = 120 - output['balls_bowled']
# C:\Users\srika\AppData\Local\Temp\ipykernel_33196\5402639.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output['balls_left'] = output['balls_left'].apply(lambda x:0 if x<0 else x)

# %%
output.head(124)
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 119         2    Australia    Sri Lanka  19.2     0                0
# 120         2    Australia    Sri Lanka  19.3     2                0
# 121         2    Australia    Sri Lanka  19.4     1                0
# 122         2    Australia    Sri Lanka  19.5     1         TD Paine
# 123         2    Australia    Sri Lanka  19.6     2                0
#
#           city  current_score over ball_no  balls_bowled  balls_left
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 119  Melbourne            158   19       2           116           4
# 120  Melbourne            160   19       3           117           3
# 121  Melbourne            161   19       4           118           2
# 122  Melbourne            162   19       5           119           1
# 123  Melbourne            164   19       6           120           0
#
# [124 rows x 12 columns]

# %%
output['player_dismissed'] = output['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
output['player_dismissed'] = output['player_dismissed'].astype('int')
# Out:
# C:\Users\srika\AppData\Local\Temp\ipykernel_33196\338702222.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output['player_dismissed'] = output['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
# C:\Users\srika\AppData\Local\Temp\ipykernel_33196\338702222.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output['player_dismissed'] = output['player_dismissed'].astype('int')

# %%
output.head(125)
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 120         2    Australia    Sri Lanka  19.3     2                 0
# 121         2    Australia    Sri Lanka  19.4     1                 0
# 122         2    Australia    Sri Lanka  19.5     1                 1
# 123         2    Australia    Sri Lanka  19.6     2                 0
# 124         2    Australia    Sri Lanka  19.7     4                 0
#
#           city  current_score over ball_no  balls_bowled  balls_left
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 120  Melbourne            160   19       3           117           3
# 121  Melbourne            161   19       4           118           2
# 122  Melbourne            162   19       5           119           1
# 123  Melbourne            164   19       6           120           0
# 124  Melbourne            168   19       7           121           0
#
# [125 rows x 12 columns]

# %%
output['player_dismissed'] = output.groupby('match_id')['player_dismissed'].cumsum()
output['wickets_left'] = 10 - output['player_dismissed']
# Out:
# C:\Users\srika\AppData\Local\Temp\ipykernel_33196\2021999509.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output['player_dismissed'] = output.groupby('match_id')['player_dismissed'].cumsum()
# C:\Users\srika\AppData\Local\Temp\ipykernel_33196\2021999509.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output['wickets_left'] = 10 - output['player_dismissed']

# %%
output.head(124)
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 119         2    Australia    Sri Lanka  19.2     0                 5
# 120         2    Australia    Sri Lanka  19.3     2                 5
# 121         2    Australia    Sri Lanka  19.4     1                 5
# 122         2    Australia    Sri Lanka  19.5     1                 6
# 123         2    Australia    Sri Lanka  19.6     2                 6
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 119  Melbourne            158   19       2           116           4
# 120  Melbourne            160   19       3           117           3
# 121  Melbourne            161   19       4           118           2
# 122  Melbourne            162   19       5           119           1
# 123  Melbourne            164   19       6           120           0
#
#      wickets_left
# 0              10
# 1              10
# 2              10
# 3              10
# 4              10
# ..            ...
# 119             5
# 120             5
# 121             5
# 122             4
# 123             4
#
# [124 rows x 13 columns]

# %%
output['crr'] = round((output['current_score']*6)/output['balls_bowled'],2)
# Out:
# C:\Users\srika\AppData\Local\Temp\ipykernel_33196\3720133810.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output['crr'] = round((output['current_score']*6)/output['balls_bowled'],2)

# %%
output.head(123)
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 118         2    Australia    Sri Lanka  19.1     4                 5
# 119         2    Australia    Sri Lanka  19.2     0                 5
# 120         2    Australia    Sri Lanka  19.3     2                 5
# 121         2    Australia    Sri Lanka  19.4     1                 5
# 122         2    Australia    Sri Lanka  19.5     1                 6
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 118  Melbourne            158   19       1           115           5
# 119  Melbourne            158   19       2           116           4
# 120  Melbourne            160   19       3           117           3
# 121  Melbourne            161   19       4           118           2
# 122  Melbourne            162   19       5           119           1
#
#      wickets_left   crr
# 0              10  0.00
# 1              10  0.00
# 2              10  2.00
# 3              10  4.50
# 4              10  3.60
# ..            ...   ...
# 118             5  8.24
# 119             5  8.17
# 120             5  8.21
# 121             5  8.19
# 122             4  8.17
#
# [123 rows x 14 columns]

# %%
groups = output.groupby('match_id')

# %%
match_ids = output['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30)['runs'].sum().values.tolist())

# %%
output['last_five'] = last_five
# Out:
# C:\Users\srika\AppData\Local\Temp\ipykernel_33196\3270546508.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output['last_five'] = last_five

# %%
output.head(40)
# Out:
#     match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0          2    Australia    Sri Lanka   0.1     0                 0
# 1          2    Australia    Sri Lanka   0.2     0                 0
# 2          2    Australia    Sri Lanka   0.3     1                 0
# 3          2    Australia    Sri Lanka   0.4     2                 0
# 4          2    Australia    Sri Lanka   0.5     0                 0
# 5          2    Australia    Sri Lanka   0.6     3                 0
# 6          2    Australia    Sri Lanka   1.1     0                 0
# 7          2    Australia    Sri Lanka   1.2     1                 0
# 8          2    Australia    Sri Lanka   1.3     0                 0
# 9          2    Australia    Sri Lanka   1.4     0                 0
# 10         2    Australia    Sri Lanka   1.5     4                 0
# 11         2    Australia    Sri Lanka   1.6     2                 0
# 12         2    Australia    Sri Lanka   2.1     1                 0
# 13         2    Australia    Sri Lanka   2.2     1                 0
# 14         2    Australia    Sri Lanka   2.3     0                 0
# 15         2    Australia    Sri Lanka   2.4     0                 0
# 16         2    Australia    Sri Lanka   2.5     4                 0
# 17         2    Australia    Sri Lanka   2.6     0                 0
# 18         2    Australia    Sri Lanka   3.1     0                 0
# 19         2    Australia    Sri Lanka   3.2     1                 0
# 20         2    Australia    Sri Lanka   3.3     1                 0
# 21         2    Australia    Sri Lanka   3.4     1                 0
# 22         2    Australia    Sri Lanka   3.5     4                 0
# 23         2    Australia    Sri Lanka   3.6     1                 0
# 24         2    Australia    Sri Lanka   4.1     3                 0
# 25         2    Australia    Sri Lanka   4.2     3                 0
# 26         2    Australia    Sri Lanka   4.3     4                 0
# 27         2    Australia    Sri Lanka   4.4     4                 0
# 28         2    Australia    Sri Lanka   4.5     1                 0
# 29         2    Australia    Sri Lanka   4.6     1                 0
# 30         2    Australia    Sri Lanka   5.1     1                 0
# 31         2    Australia    Sri Lanka   5.2     1                 0
# 32         2    Australia    Sri Lanka   5.3     0                 0
# 33         2    Australia    Sri Lanka   5.4     0                 0
# 34         2    Australia    Sri Lanka   5.5     1                 0
# 35         2    Australia    Sri Lanka   5.6     1                 0
# 36         2    Australia    Sri Lanka   5.7     0                 0
# 37         2    Australia    Sri Lanka   6.1     1                 0
# 38         2    Australia    Sri Lanka   6.2     1                 0
# 39         2    Australia    Sri Lanka   6.3     0                 0
#
#          city  current_score over ball_no  balls_bowled  balls_left  \
# 0   Melbourne              0    0       1             1         119
# 1   Melbourne              0    0       2             2         118
# 2   Melbourne              1    0       3             3         117
# 3   Melbourne              3    0       4             4         116
# 4   Melbourne              3    0       5             5         115
# 5   Melbourne              6    0       6             6         114
# 6   Melbourne              6    1       1             7         113
# 7   Melbourne              7    1       2             8         112
# 8   Melbourne              7    1       3             9         111
# 9   Melbourne              7    1       4            10         110
# 10  Melbourne             11    1       5            11         109
# 11  Melbourne             13    1       6            12         108
# 12  Melbourne             14    2       1            13         107
# 13  Melbourne             15    2       2            14         106
# 14  Melbourne             15    2       3            15         105
# 15  Melbourne             15    2       4            16         104
# 16  Melbourne             19    2       5            17         103
# 17  Melbourne             19    2       6            18         102
# 18  Melbourne             19    3       1            19         101
# 19  Melbourne             20    3       2            20         100
# 20  Melbourne             21    3       3            21          99
# 21  Melbourne             22    3       4            22          98
# 22  Melbourne             26    3       5            23          97
# 23  Melbourne             27    3       6            24          96
# 24  Melbourne             30    4       1            25          95
# 25  Melbourne             33    4       2            26          94
# 26  Melbourne             37    4       3            27          93
# 27  Melbourne             41    4       4            28          92
# 28  Melbourne             42    4       5            29          91
# 29  Melbourne             43    4       6            30          90
# 30  Melbourne             44    5       1            31          89
# 31  Melbourne             45    5       2            32          88
# 32  Melbourne             45    5       3            33          87
# 33  Melbourne             45    5       4            34          86
# 34  Melbourne             46    5       5            35          85
# 35  Melbourne             47    5       6            36          84
# 36  Melbourne             47    5       7            37          83
# 37  Melbourne             48    6       1            37          83
# 38  Melbourne             49    6       2            38          82
# 39  Melbourne             49    6       3            39          81
#
#     wickets_left   crr  last_five
# 0             10  0.00        NaN
# 1             10  0.00        NaN
# 2             10  2.00        NaN
# 3             10  4.50        NaN
# 4             10  3.60        NaN
# 5             10  6.00        NaN
# 6             10  5.14        NaN
# 7             10  5.25        NaN
# 8             10  4.67        NaN
# 9             10  4.20        NaN
# 10            10  6.00        NaN
# 11            10  6.50        NaN
# 12            10  6.46        NaN
# 13            10  6.43        NaN
# 14            10  6.00        NaN
# 15            10  5.62        NaN
# 16            10  6.71        NaN
# 17            10  6.33        NaN
# 18            10  6.00        NaN
# 19            10  6.00        NaN
# 20            10  6.00        NaN
# 21            10  6.00        NaN
# 22            10  6.78        NaN
# 23            10  6.75        NaN
# 24            10  7.20        NaN
# 25            10  7.62        NaN
# 26            10  8.22        NaN
# 27            10  8.79        NaN
# 28            10  8.69        NaN
# 29            10  8.60       43.0
# 30            10  8.52       44.0
# 31            10  8.44       45.0
# 32            10  8.18       44.0
# 33            10  7.94       42.0
# 34            10  7.89       43.0
# 35            10  7.83       41.0
# 36            10  7.62       41.0
# 37            10  7.78       41.0
# 38            10  7.74       42.0
# 39            10  7.54       42.0

# %%
total_df = output.groupby('match_id').sum()['runs'].reset_index()
output = output.merge(total_df,on='match_id')

# %%
output
# Out:
#        match_id batting_team bowling_team  ball  runs_x  player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1       0                 0
# 1             2    Australia    Sri Lanka   0.2       0                 0
# 2             2    Australia    Sri Lanka   0.3       1                 0
# 3             2    Australia    Sri Lanka   0.4       2                 0
# 4             2    Australia    Sri Lanka   0.5       0                 0
# ...         ...          ...          ...   ...     ...               ...
# 71951      1647    Sri Lanka    Australia  19.3       1                 8
# 71952      1647    Sri Lanka    Australia  19.4       0                 8
# 71953      1647    Sri Lanka    Australia  19.5       0                 9
# 71954      1647    Sri Lanka    Australia  19.6       2                 9
# 71955      1647    Sri Lanka    Australia  19.7       1                 9
#
#             city  current_score over ball_no  balls_bowled  balls_left  \
# 0      Melbourne              0    0       1             1         119
# 1      Melbourne              0    0       2             2         118
# 2      Melbourne              1    0       3             3         117
# 3      Melbourne              3    0       4             4         116
# 4      Melbourne              3    0       5             5         115
# ...          ...            ...  ...     ...           ...         ...
# 71951    Colombo            125   19       3           117           3
# 71952    Colombo            125   19       4           118           2
# 71953    Colombo            125   19       5           119           1
# 71954    Colombo            127   19       6           120           0
# 71955    Colombo            128   19       7           121           0
#
#        wickets_left   crr  last_five  runs_y
# 0                10  0.00        NaN     168
# 1                10  0.00        NaN     168
# 2                10  2.00        NaN     168
# 3                10  4.50        NaN     168
# 4                10  3.60        NaN     168
# ...             ...   ...        ...     ...
# 71951             2  6.41       32.0     128
# 71952             2  6.36       32.0     128
# 71953             1  6.30       32.0     128
# 71954             1  6.35       33.0     128
# 71955             1  6.35       32.0     128
#
# [71956 rows x 16 columns]

# %%
# final_df = output[['match_id','batting_team','bowling_team','runs_x','current_score','balls_bowled','wickets_left','crr','city','runs_y']]

# %%
final_df = output[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_y']]

# %%
final_df.dropna(inplace=True)
# Out:
# C:\Users\srika\AppData\Local\Temp\ipykernel_33196\2709626079.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.dropna(inplace=True)

# %%
final_df
# Out:
#       batting_team bowling_team       city  current_score  balls_left  \
# 29       Australia    Sri Lanka  Melbourne             43          90
# 30       Australia    Sri Lanka  Melbourne             44          89
# 31       Australia    Sri Lanka  Melbourne             45          88
# 32       Australia    Sri Lanka  Melbourne             45          87
# 33       Australia    Sri Lanka  Melbourne             45          86
# ...            ...          ...        ...            ...         ...
# 71951    Sri Lanka    Australia    Colombo            125           3
# 71952    Sri Lanka    Australia    Colombo            125           2
# 71953    Sri Lanka    Australia    Colombo            125           1
# 71954    Sri Lanka    Australia    Colombo            127           0
# 71955    Sri Lanka    Australia    Colombo            128           0
#
#        wickets_left   crr  last_five  runs_y
# 29               10  8.60       43.0     168
# 30               10  8.52       44.0     168
# 31               10  8.44       45.0     168
# 32               10  8.18       44.0     168
# 33               10  7.94       42.0     168
# ...             ...   ...        ...     ...
# 71951             2  6.41       32.0     128
# 71952             2  6.36       32.0     128
# 71953             1  6.30       32.0     128
# 71954             1  6.35       33.0     128
# 71955             1  6.35       32.0     128
#
# [54857 rows x 9 columns]

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#        batting_team bowling_team          city  current_score  balls_left  \
# 65445  South Africa   Bangladesh        Mirpur             67          76
# 66387  South Africa    Australia  Johannesburg            198           1
# 36367   West Indies      England        London             58          71
# 46426     Australia    Sri Lanka      Barbados             67          56
# 64231   New Zealand     Pakistan         Dubai             73          53
# ...             ...          ...           ...            ...         ...
# 1193          India      England     Bangalore             92          50
# 182       Australia    Sri Lanka      Adelaide             83          65
# 34942       England    Australia   Southampton            152          16
# 2467        England  New Zealand      Hamilton            125          34
# 11972         India  West Indies        Mumbai             85          75
#
#        wickets_left    crr  last_five  runs_y
# 65445            10   9.14       41.0     169
# 66387             3   9.98       55.0     204
# 36367             9   7.10       27.0     169
# 46426             6   6.28       35.0     168
# 64231             6   6.54       37.0     135
# ...             ...    ...        ...     ...
# 1193              8   7.89       30.0     202
# 182               9   9.05       43.0     187
# 34942             5   8.77       45.0     179
# 2467              6   8.72       40.0     194
# 11972            10  11.33       60.0     240
#
# [54857 rows x 9 columns]

# %%
final_df.to_csv('dataset_level3_trunc.csv',index=False)

# %%
final_df = pd.read_csv('dataset_level3.csv')

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#        batting_team bowling_team        city  current_score  balls_left  \
# 13197     Sri Lanka    Australia     Colombo            103          39
# 2524       Pakistan        India       Dubai            120          13
# 16456  South Africa  New Zealand    Barbados             55          72
# 36604   West Indies      England   Pallekele            142          22
# 6880     Bangladesh  New Zealand      Napier             70          51
# ...             ...          ...         ...            ...         ...
# 3525      Australia    Sri Lanka      Sydney             53          68
# 23936       England     Pakistan  Manchester             46          77
# 13545       England     Pakistan   Abu Dhabi             62          61
# 28300  South Africa     Pakistan     Colombo             53          53
# 21348         India   Bangladesh       Delhi             34          86
#
#        wickets_left   crr  last_five  runs_y
# 13197             7  7.63       37.0     128
# 2524              3  6.73       30.0     147
# 16456             8  6.88       28.0     170
# 36604             7  8.69       34.0     179
# 6880              5  6.09       33.0     141
# ...             ...   ...        ...     ...
# 3525              8  6.12       29.0     137
# 23936             9  6.42       38.0     131
# 13545             7  6.31       29.0     129
# 28300             7  4.75       25.0     133
# 21348             9  6.00       28.0     148
#
# [64686 rows x 9 columns]

# %% [markdown]
# # 3) Dagshub MLFlow Setup

# %%
import mlflow
import dagshub

mlflow.set_tracking_uri('https://dagshub.com/srikara202/Cricket-T20-Score-Predictor-MLOps.mlflow')
dagshub.init(repo_owner='srikara202', repo_name='Cricket-T20-Score-Predictor-MLOps', mlflow=True)

mlflow.set_experiment('XGBoost Regressor Pipeline')
# Out:
# Initialized MLflow to track repo "srikara202/Cricket-T20-Score-Predictor-MLOps"
# Repository srikara202/Cricket-T20-Score-Predictor-MLOps initialized!
# <Experiment: artifact_location='mlflow-artifacts:/fe7075ca132b4da4a90741c5f4b57318', creation_time=1752417703229, experiment_id='0', last_update_time=1752417703229, lifecycle_stage='active', name='XGBoost Regressor Pipeline', tags={}>

# %% [markdown]
# # 4) Train Test Split

# %%
X = final_df.drop(columns=['runs_y'])
y = final_df['runs_y']
from sklearn.model_selection import train_test_split
ts = 0.5
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=ts,random_state=1)

# %% [markdown]
# # 4) Model Training, Validation, Evaluation

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error,root_mean_squared_error

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse_output=False,handle_unknown="ignore"),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.1,max_depth=10,random_state=1))
])

# %%
from sklearn.model_selection import KFold, cross_validate

# ---------------------------------------------------
# 2) Standard K‑Fold Cross‑Validation
# ---------------------------------------------------
kf = KFold(n_splits=5, shuffle=True, random_state=42)
scoring = {
    'r2': 'r2',
    'mse': 'neg_mean_squared_error',
    'mae': 'neg_mean_absolute_error'
}

cv_results = cross_validate(pipe, X_train, y_train, cv=kf, scoring=scoring)

r2_scores   = cv_results['test_r2']
rmse_scores = np.sqrt(-cv_results['test_mse'])
mae_scores  = -cv_results['test_mae']

print(f"K-Fold CV R²:   {r2_scores.mean():.4f} ± {r2_scores.std():.4f}")
print(f"K-Fold CV RMSE: {rmse_scores.mean():.4f} ± {rmse_scores.std():.4f}")
print(f"K-Fold CV MAE:  {mae_scores.mean():.4f} ± {mae_scores.std():.4f}")
# Out:
# K-Fold CV R²:   0.9757 ± 0.0018
# K-Fold CV RMSE: 5.2637 ± 0.1785
# K-Fold CV MAE:  2.7154 ± 0.0275

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
y_train_pred = pipe.predict(X_train)
print(r2_score(y_train,y_train_pred))
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(root_mean_squared_error(y_test, y_pred))
# Out:
# 0.9996429681777954
# 0.980977475643158
# 2.379725299105479
# 4.648104231638435

# %%
teams
# Out:
# ['Australia',
#  'India',
#  'Bangladesh',
#  'New Zealand',
#  'South Africa',
#  'England',
#  'West Indies',
#  'Pakistan',
#  'Sri Lanka']

# %%
X_new = pd.DataFrame([{
    'batting_team':  'India',
    'bowling_team':  'England',
    'city':          'Pune',
    'current_score': 72,
    'balls_left':    60,
    'wickets_left':  6,
    'crr':            7.2,
    'last_five':     35
}])

pipe.predict(X_new)[0]
# Out:
# 155.63799

# %%
'Rajkot' in eligible_cities
# Out:
# True

# %% [markdown]
# # 5) Experiment Tracking using Dagshub and MLFlow

# %%
# import logging
# import os
# import time
# import shutil
# from sklearn.compose import ColumnTransformer
# from sklearn.preprocessing import OneHotEncoder
# from sklearn.pipeline import Pipeline
# from sklearn.preprocessing import StandardScaler
# from sklearn.ensemble import RandomForestRegressor
# from xgboost import XGBRegressor
# from sklearn.metrics import r2_score,mean_absolute_error,root_mean_squared_error

# # Configure logging
# logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

# logging.info("Starting MLflow run...")

# with mlflow.start_run():
#     start_time = time.time()
    
#     try:
#         logging.info("Logging preprocessing parameters...")
#         n_estimators=700
#         learning_rate=0.3
#         max_depth=14
#         mlflow.log_param("test_size", ts)

#         logging.info("Initializing XGBoost Regression model with Column Transformer...")
#         trf = ColumnTransformer([
#             ('trf',OneHotEncoder(sparse_output=False,drop='first'),['batting_team','bowling_team','city'])
#         ]
#         ,remainder='passthrough')
#         model = Pipeline(steps=[
#             ('step1',trf),
#             ('step2',StandardScaler()),
#             ('step3',XGBRegressor(n_estimators=n_estimators,learning_rate=learning_rate,max_depth=max_depth,random_state=1))
#         ])
        

#         logging.info("Fitting the model...")
#         model.fit(X_train, y_train)
#         logging.info("Model training complete.")

#         logging.info("Logging model parameters...")
#         mlflow.log_param("model", "Logistic Regression")
#         mlflow.log_param("n_estimators", n_estimators)
#         mlflow.log_param("learning_rate",learning_rate)
#         mlflow.log_param("max_depth", max_depth)

#         logging.info("Making predictions...")
#         y_pred = model.predict(X_test)

#         logging.info("Calculating evaluation metrics...")
#         r2s = r2_score(y_test,y_pred)
#         mae = mean_absolute_error(y_test,y_pred)
#         rmse = root_mean_squared_error(y_test,y_pred)

#         logging.info("Logging evaluation metrics...")
#         mlflow.log_metric("r2_score", r2s)
#         mlflow.log_metric("mean_absolute_error",mae)
#         mlflow.log_metric("root_mean_squared_error",rmse)
        
#         logging.info("Saving and logging the model...")
#         # If it’s there already, blow it away
#         model_dir = "model_dir"
#         if os.path.exists(model_dir):
#             shutil.rmtree(model_dir)
#         # Now save + upload
#         mlflow.sklearn.save_model(sk_model=model, path=model_dir)
#         mlflow.log_artifacts(model_dir, artifact_path="model")

#         # Log execution time
#         end_time = time.time()
#         logging.info(f"Model training and logging completed in {end_time - start_time:.2f} seconds.")

#         # Save and log the notebook
#         # notebook_path = "exp1_baseline_model.ipynb"
#         # logging.info("Executing Jupyter Notebook. This may take a while...")
#         # os.system(f"jupyter nbconvert --to notebook --execute --inplace {notebook_path}")
#         # mlflow.log_artifact(notebook_path)

#         # logging.info("Notebook execution and logging complete.")

#         # Print the results for verification
#         logging.info(f"r2_score: {r2s}")
#         logging.info(f"mean_absolute_error: {mae}")
#         logging.info(f"root_mean_squared_error: {rmse}")

#     except Exception as e:
#         logging.error(f"An error occurred: {e}", exc_info=True)
# Out:
# 2025-07-14 03:27:07,906 - INFO - Starting MLflow run...
# 2025-07-14 03:27:08,238 - INFO - Logging preprocessing parameters...
# 2025-07-14 03:27:08,548 - INFO - Initializing XGBoost Regression model with Column Transformer...
# 2025-07-14 03:27:08,554 - INFO - Fitting the model...
# 2025-07-14 03:27:09,535 - INFO - Model training complete.
# 2025-07-14 03:27:09,537 - INFO - Logging model parameters...
# 2025-07-14 03:27:10,693 - INFO - Making predictions...
# 2025-07-14 03:27:10,706 - INFO - Calculating evaluation metrics...
# 2025-07-14 03:27:10,711 - INFO - Logging evaluation metrics...
# 2025-07-14 03:27:13,294 - INFO - Saving and logging the model...
# 2025-07-14 03:27:24,209 - INFO - Model training and logging completed in 15.97 seconds.
# 2025-07-14 03:27:24,210 - INFO - r2_score: 0.982562243938446
# 2025-07-14 03:27:24,211 - INFO - mean_absolute_error: 0.7808371782302856
# 2025-07-14 03:27:24,211 - INFO - root_mean_squared_error: 3.682307243347168
# 🏃 View run adaptable-robin-357 at: https://dagshub.com/srikara202/Cricket-T20-Score-Predictor-MLOps.mlflow/#/experiments/0/runs/86e4cd81652c404981ad6bd3eddfb2bb
# 🧪 View experiment at: https://dagshub.com/srikara202/Cricket-T20-Score-Predictor-MLOps.mlflow/#/experiments/0

# %%
# import pandas as pd
# from sklearn.model_selection import GridSearchCV, KFold
# from sklearn.pipeline import Pipeline
# from sklearn.compose import ColumnTransformer
# from sklearn.preprocessing import OneHotEncoder, StandardScaler
# from xgboost import XGBRegressor

# # ─────────────────────────────────────────────────────────────────────────────
# # 1. LOAD / PREP YOUR DATA
# # ─────────────────────────────────────────────────────────────────────────────
# # (Replace with your own data-loading code)
# # df = pd.read_csv("…")
# X = X_train
# y = y_train

# # ─────────────────────────────────────────────────────────────────────────────
# # 2. DEFINE FEATURE GROUPS
# # ─────────────────────────────────────────────────────────────────────────────
# cat_cols = ['batting_team', 'bowling_team', 'city']
# num_cols = ['current_score', 'balls_left', 'wickets_left', 'crr', 'last_five']

# # ─────────────────────────────────────────────────────────────────────────────
# # 3. BUILD PREPROCESSOR + PIPELINE
# # ─────────────────────────────────────────────────────────────────────────────
# preprocessor = ColumnTransformer([
#     ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False), cat_cols),
#     ('scale',  StandardScaler(), num_cols)
# ])

# pipe = Pipeline([
#     ('preprocess', preprocessor),
#     ('model',      XGBRegressor(objective='reg:squarederror', random_state=1))
# ])

# # ─────────────────────────────────────────────────────────────────────────────
# # 4. SET UP PARAM GRID FOR XGBOOST
# # ─────────────────────────────────────────────────────────────────────────────
# param_grid = {
#     # tree booster
#     'n_estimators':    [100, 300, 600, 1000, 1200, 1500],
#     'max_depth':       [3, 6, 10, 12, 15, 18],
#     'learning_rate':   [0.01, 0.05, 0.1, 0.2],
# }

# # ─────────────────────────────────────────────────────────────────────────────
# # 5. CONFIGURE CROSS-VALIDATION
# # ─────────────────────────────────────────────────────────────────────────────
# cv = KFold(n_splits=5, shuffle=True, random_state=1)

# grid = GridSearchCV(
#     estimator   = pipe,
#     param_grid  = param_grid,
#     cv          = cv,
#     scoring     = 'neg_root_mean_squared_error',  # returns –RMSE
#     n_jobs      = -1,
#     verbose     = 2
# )

# # ─────────────────────────────────────────────────────────────────────────────
# # 6. RUN THE GRID SEARCH
# # ─────────────────────────────────────────────────────────────────────────────
# grid.fit(X, y)

# # ─────────────────────────────────────────────────────────────────────────────
# # 7. RESULTS
# # ─────────────────────────────────────────────────────────────────────────────
# best_rmse   = -grid.best_score_
# best_params =  grid.best_params_

# print(f"▶︎ Best CV RMSE: {best_rmse:.3f}")
# print("▶︎ Best parameters:")
# for p, v in best_params.items():
#     print(f"   • {p}: {v}")
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# ▶︎ Best CV RMSE: 2.225
# ▶︎ Best parameters:
#    • model__learning_rate: 0.05
#    • model__max_depth: 6
#    • model__n_estimators: 1500

# %%
import logging, os, shutil, time
import mlflow
import numpy as np
import pandas as pd

from sklearn.model_selection    import train_test_split, GridSearchCV, KFold
from sklearn.compose            import ColumnTransformer
from sklearn.preprocessing      import OneHotEncoder, StandardScaler
from sklearn.pipeline           import Pipeline
from xgboost                    import XGBRegressor
from sklearn.metrics            import r2_score, mean_absolute_error, mean_squared_error


mlflow.set_experiment('XGBoost Regressor CV')

# ─────────────────────────────────────────────────────────────────────────────
# 0. CONFIGURE LOGGING
# ─────────────────────────────────────────────────────────────────────────────
logging.basicConfig(level=logging.INFO, format="%(asctime)s %(levelname)s %(message)s")

# ─────────────────────────────────────────────────────────────────────────────
# 1. LOAD YOUR DATA
# ─────────────────────────────────────────────────────────────────────────────
# assume df is your DataFrame and 'runs_y' is the target
# df = pd.read_csv("…")
X = final_df.drop(columns=['runs_y'])
y = final_df['runs_y']

# ─────────────────────────────────────────────────────────────────────────────
# 2. SPLIT TRAIN / TEST
# ─────────────────────────────────────────────────────────────────────────────
test_size = 0.2
random_state = 1
logging.info(f"Splitting data, test_size={test_size}")
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=test_size, random_state=random_state
)

# ─────────────────────────────────────────────────────────────────────────────
# 3. DEFINE PREPROCESSOR + PIPELINE
# ─────────────────────────────────────────────────────────────────────────────
cat_cols = ['batting_team', 'bowling_team', 'city']
num_cols = ['current_score', 'balls_left', 'wickets_left', 'crr', 'last_five']

preprocessor = ColumnTransformer([
    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False), cat_cols),
    ('scale',  StandardScaler(),                      num_cols)
])

pipe = Pipeline([
    ('preprocess', preprocessor),
    ('model',      XGBRegressor(
        objective='reg:squarederror',
        random_state=random_state
    ))
])

# ─────────────────────────────────────────────────────────────────────────────
# 4. SET UP PARAM GRID
# ─────────────────────────────────────────────────────────────────────────────
param_grid = {
    'model__n_estimators':    [200,400,600,800,1000],
    'model__max_depth':       [6,8,10,12,14,16],
    'model__learning_rate':   [0.01,0.05,0.1,0.2]
}

# ─────────────────────────────────────────────────────────────────────────────
# 5. GRIDSEARCHCV with 5-fold CV
# ─────────────────────────────────────────────────────────────────────────────
cv = KFold(n_splits=5, shuffle=True, random_state=random_state)

grid = GridSearchCV(
    estimator  = pipe,
    param_grid = param_grid,
    cv         = cv,
    scoring    = 'neg_root_mean_squared_error',
    n_jobs     = -1,
    verbose    = 2,
)

# ─────────────────────────────────────────────────────────────────────────────
# 6. MLflow RUN
# ─────────────────────────────────────────────────────────────────────────────
with mlflow.start_run():
    start_time = time.time()
    # log basic run params
    mlflow.log_param("test_size",    test_size)
    mlflow.log_param("model_name",  "XGBRegressor")

    logging.info("Starting GridSearchCV …")
    grid.fit(X_train, y_train)
    logging.info("GridSearchCV complete.")

    # log every CV combo’s mean & std RMSE
    cv_res = grid.cv_results_
    for i, (mean_score, std_score, params) in enumerate(
        zip(cv_res['mean_test_score'], cv_res['std_test_score'], cv_res['params'])
    ):
        mean_rmse = -mean_score
        mlflow.log_metric(f"cv_{i}_mean_rmse", mean_rmse)
        mlflow.log_metric(f"cv_{i}_std_rmse",  std_score)
        # also log the param values for this combo
        for p_name, p_val in params.items():
            mlflow.log_param(f"cv_{i}_{p_name}", p_val)

    # best CV results
    best_rmse   = -grid.best_score_
    best_params =  grid.best_params_
    mlflow.log_metric("cv_best_rmse", best_rmse)
    for p_name, p_val in best_params.items():
        mlflow.log_param(f"best_{p_name}", p_val)

    logging.info(f"Best CV RMSE = {best_rmse:.4f}")
    logging.info(f"Best params   = {best_params}")

    # ─────────────────────────────────────────────────────────────────────────
    # 7. EVALUATE ON HELD-OUT TEST SET
    # ─────────────────────────────────────────────────────────────────────────
    logging.info("Evaluating best model on test set …")
    best_model = grid.best_estimator_
    y_pred     = best_model.predict(X_test)

    r2   = r2_score(y_test, y_pred)
    mae  = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))

    mlflow.log_metric("test_r2_score",                r2)
    mlflow.log_metric("test_mean_absolute_error",     mae)
    mlflow.log_metric("test_root_mean_squared_error", rmse)

    logging.info(f"Test R²   = {r2:.4f}")
    logging.info(f"Test MAE  = {mae:.4f}")
    logging.info(f"Test RMSE = {rmse:.4f}")

    # ─────────────────────────────────────────────────────────────────────────
    # 8. SAVE & LOG FINAL MODEL
    # ─────────────────────────────────────────────────────────────────────────
    model_dir = "xgb_cv_model"
    if os.path.exists(model_dir):
        shutil.rmtree(model_dir)
    mlflow.sklearn.save_model(best_model, path=model_dir)
    mlflow.log_artifacts(model_dir, artifact_path="model")

    elapsed = time.time() - start_time
    logging.info(f"Run completed in {elapsed:.1f}s")
# Out:
# 2025-07-19 14:06:40,964 INFO Splitting data, test_size=0.2
# 2025-07-19 14:06:41,869 INFO Starting GridSearchCV …
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# 2025-07-19 14:39:31,426 INFO GridSearchCV complete.
# 2025-07-19 14:39:32,722 INFO Best CV RMSE = 4.2029
# 2025-07-19 14:39:32,724 INFO Best params   = {'model__learning_rate': 0.1, 'model__max_depth': 10, 'model__n_estimators': 1000}
# 2025-07-19 14:39:32,725 INFO Evaluating best model on test set …
# 2025-07-19 14:39:33,782 INFO Test R²   = 0.9888
# 2025-07-19 14:39:33,784 INFO Test MAE  = 1.7872
# 2025-07-19 14:39:33,785 INFO Test RMSE = 3.5708
# c:\Users\srika\anaconda3\envs\atlas310\lib\site-packages\_distutils_hack\__init__.py:15: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# c:\Users\srika\anaconda3\envs\atlas310\lib\site-packages\_distutils_hack\__init__.py:30: UserWarning: Setuptools is replacing distutils. Support for replacing an already imported distutils is deprecated. In the future, this condition will fail. Register concerns at https://github.com/pypa/setuptools/issues/new?template=distutils-deprecation.yml
#   warnings.warn(
# 2025-07-19 14:39:51,971 INFO Run completed in 1990.7s
# 2025/07/19 14:39:55 INFO mlflow.tracking._tracking_service.client: 🏃 View run skillful-stork-224 at: https://dagshub.com/srikara202/Cricket-T20-Score-Predictor-MLOps.mlflow/#/experiments/3/runs/54a73af61edb4a63b827be84aee03af1.
# 2025/07/19 14:39:55 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/srikara202/Cricket-T20-Score-Predictor-MLOps.mlflow/#/experiments/3.

# %%
# import pandas as pd
# from sklearn.model_selection import GridSearchCV, KFold
# from sklearn.pipeline import Pipeline
# from sklearn.compose import ColumnTransformer
# from sklearn.preprocessing import OneHotEncoder, StandardScaler

# from xgboost import XGBRegressor
# from lightgbm import LGBMRegressor
# from catboost import CatBoostRegressor
# from sklearn.ensemble import HistGradientBoostingRegressor, ExtraTreesRegressor

# mlflow.set_experiment('Cross Validation')

# # ─────────────────────────────────────────────────────────────────────────────
# # 1. LOAD YOUR DATA
# # ─────────────────────────────────────────────────────────────────────────────
# # assume `df` is your DataFrame and 'runs_y' is the target
# # df = pd.read_csv("…")
# X = X_train
# y = X_test

# # ─────────────────────────────────────────────────────────────────────────────
# # 2. FEATURE LISTS
# # ─────────────────────────────────────────────────────────────────────────────
# cat_cols = ['batting_team', 'bowling_team', 'city']
# num_cols = ['current_score', 'balls_left', 'wickets_left', 'crr', 'last_five']

# # ─────────────────────────────────────────────────────────────────────────────
# # 3. PREPROCESSOR FOR ONE-HOT + SCALE
# # ─────────────────────────────────────────────────────────────────────────────
# preprocessor = ColumnTransformer([
#     ('onehot', OneHotEncoder(handle_unknown='ignore'), cat_cols),
#     ('scale', StandardScaler(), num_cols)
# ])

# # ─────────────────────────────────────────────────────────────────────────────
# # 4. DEFINE PIPELINES + PARAM-GRIDS
# # ─────────────────────────────────────────────────────────────────────────────
# models = {
#     'xgb': {
#         'pipeline': Pipeline([
#             ('preprocess', preprocessor),
#             ('model', XGBRegressor(objective='reg:squarederror', random_state=1))
#         ]),
#         'params': {
#             'model__n_estimators': [100, 500, 1000],
#             'model__learning_rate': [0.01, 0.1, 0.2],
#             'model__max_depth': [3, 6, 12]
#         }
#     },
#     'lgbm': {
#         'pipeline': Pipeline([
#             ('preprocess', preprocessor),
#             ('model', LGBMRegressor(random_state=1))
#         ]),
#         'params': {
#             'model__n_estimators': [100, 500, 1000],
#             'model__learning_rate': [0.01, 0.05, 0.1],
#             'model__max_depth': [-1, 6, 12]
#         }
#     },
#     'cat': {
#         # CatBoost handles cats natively → no OHE or scaling
#         'pipeline': Pipeline([
#             ('model', CatBoostRegressor(verbose=0, random_state=1))
#         ]),
#         'params': {
#             'model__iterations':  [500, 1000],
#             'model__learning_rate': [0.03, 0.1],
#             'model__depth': [6, 8, 10]
#         },
#         'fit_params': {
#             'model__cat_features': cat_cols
#         }
#     },
#     'histgb': {
#         'pipeline': Pipeline([
#             ('preprocess', preprocessor),
#             ('model', HistGradientBoostingRegressor(random_state=1))
#         ]),
#         'params': {
#             'model__max_iter':       [100, 300],
#             'model__max_depth':      [None, 6, 12],
#             'model__learning_rate':  [0.01, 0.1]
#         }
#     },
#     'extratree': {
#         # trees → no scaling; only OHE for cats
#         'pipeline': Pipeline([
#             ('preprocess', ColumnTransformer([
#                 ('onehot', OneHotEncoder(handle_unknown='ignore'), cat_cols)
#             ], remainder='passthrough')),
#             ('model', ExtraTreesRegressor(random_state=1))
#         ]),
#         'params': {
#             'model__n_estimators':   [100, 500, 1000],
#             'model__max_features':   ['auto','sqrt','log2']
#         }
#     }
# }

# # ─────────────────────────────────────────────────────────────────────────────
# # 5. RUN GRID-SEARCH CV
# # ─────────────────────────────────────────────────────────────────────────────
# cv = KFold(n_splits=5, shuffle=True, random_state=1)
# results = {}

# for name, m in models.items():
#     print(f"\n▶︎ Running GridSearchCV for {name} …")
#     gs = GridSearchCV(
#         estimator   = m['pipeline'],
#         param_grid  = m['params'],
#         cv          = cv,
#         scoring     = 'neg_root_mean_squared_error',
#         n_jobs      = -1,
#         verbose     = 2
#     )
#     # pass cat_features for CatBoost only
#     if 'fit_params' in m:
#         gs.fit(X, y, **m['fit_params'])
#     else:
#         gs.fit(X, y)

#     best_rmse     = -gs.best_score_
#     best_params   = gs.best_params_
#     results[name] = (best_rmse, best_params)

#     print(f"✔ {name:8s}  best RMSE = {best_rmse:.3f}")
#     print("  params →", best_params)

# # ─────────────────────────────────────────────────────────────────────────────
# # 6. OPTIONAL: SUMMARY TABLE
# # ─────────────────────────────────────────────────────────────────────────────
# summary = pd.DataFrame.from_dict(
#     {k: {'rmse': v[0], 'params': v[1]} for k, v in results.items()},
#     orient='index'
# ).sort_values('rmse')
# print("\nAll models ranked by best RMSE:\n", summary)
